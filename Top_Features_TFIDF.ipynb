# %%
# See Top Features - Train all models using the best classifier that has coef_ function available
# LinearSVC, in this case.
# Challenges - May only be interested in using the top models indicated by Load_Pickle.ipynb's final_results accuracies.
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import sklearn
import nltk
from sklearn import naive_bayes
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, NuSVC, LinearSVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis 
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from math import sqrt
import joblib
import string
import re
import sys
import datetime
import html
import os
import timeit
nltk.download('punkt')
nltk.download('wordnet')

# sklearn=0.23.1, pandas=1.0.1
print(sklearn.__version__)
print(pd.__version__)
# Out:
# 0.23.1
# 1.0.1
# [nltk_data] Downloading package punkt to C:\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Gather Data

# %% [markdown]
# ### 2 sources

# %%
# Let's see what features we have.
length_req = 800  # Character length requirement for articles
confidence_level = .90

left1 = pd.read_excel("csvs/Huffington.xlsx", 
                  names=["date", "article"])
#left1 = pd.read_csv('Huffington.csv')
print("We have {:,} left1-wing records".format(left1.shape[0]))

left1['date'].fillna("", inplace=True)
left1['article'].fillna("", inplace=True)
    
for x in range(left1.shape[0]):
    if len(left1['article'][x]) < length_req:
        left1.drop(x, inplace=True)

print("We have {:,} left1-wing records > {} characters long".format(left1.shape[0], length_req))

# Only keep the unique article rows and their values
left1.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    left1.shape[0]))

left1['date'] = left1['date'].str.replace(',', '')

left1.head()
# Out:
# We have 4,355 left1-wing records
# We have 4,314 left1-wing records > 800 characters long
# 4,304 Records are unique
#           date                                            article
# 0  2020-01-01   Elizabeth Warren Rips ‘Fawning, Spineless’ Rep...
# 1  2020-01-01   These Major New Laws Take Effect Today From ma...
# 2  2020-01-01   U.S. To Deploy Hundreds Of Troops To Iraq Afte...
# 3  2020-01-01   Police And Protesters Clash In New Year’s Rall...
# 4  2020-01-01   Trump Shrugs Off Kim Jong Un’s Nuclear Testing...

# %%
# Let's see what features we have.
right1 = pd.read_excel("csvs/NewsMax.xlsx",
                     names=["date", "article"])
print("We have {:,} right1-wing records".format(right1.shape[0]))

right1['date'].fillna("", inplace=True)
right1['article'].fillna("", inplace=True)

for x in range(right1.shape[0]):
    if len(right1['article']) < length_req:
        right1.drop(x, inplace=True)

print("We have {:,} right1-wing records > {} characters long".format(right1.shape[0], length_req))

# Only keep the unique rows and their values
right1.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    right1.shape[0]))

right1['date'] = right1['date'].str.replace(',', '')

right1.head()
# Out:
# We have 5,829 right1-wing records
# We have 5,829 right1-wing records > 800 characters long
# 5,780 Records are unique
#           date                                            article
# 0  2020-01-01   Klobuchar Hits Trump's Golf: 'I Spent 0 Days' ...
# 1  2020-01-01   WashPost: Bloomberg's China Ties Are Conflict ...
# 2  2020-01-01   James Woolsey to Newsmax TV: Target the IRGC N...
# 3  2020-01-01   Report: US Service Members Killed in Afghanist...
# 4  2020-01-01   Bernie Kerik to Newsmax TV: Trump Sends World ...

# %%
# Check for null values
right1.isnull().sum(axis=0)
# Out:
# date       0
# article    0
# dtype: int64

# %%
left1.isnull().sum(axis=0)
# Out:
# date       0
# article    0
# dtype: int64

# %%
# If there were null values, the below will replace them.
left1['date'].fillna("", inplace=True)
right1['date'].fillna("", inplace=True)
#right['article'].fillna("", inplace=True)
#right.isnull().sum(axis=0)

# %%
# Search for non-null valued rows
# Useful for fixing when data went into three or more columns instead of two in the Excel sheet.
#left[left['date'].notnull()]
#right[right['date'].notnull()]

# Finds all null valued rows
left1[~left1['date'].notnull()]
#right[~right['date'].notnull()]
# Out:
# Empty DataFrame
# Columns: [date, article]
# Index: []

# %%
left1['pole'] = 0  # Make a column 'pole', assign a value of 0 to indicate left1 articles
print("We have {:,} left1-wing records".format(left1.shape[0]))
right1['pole'] = 1
print("We have {:,} right1-wing records".format(right1.shape[0]))

if (right1.shape[0] > left1.shape[0]):
    print("Getting random sample of right1-wing records")
    right1 = right1.sample(left1.shape[0]) # randomly generate samples from right1 equal to left1's length. (Can be set to random_state=0)
else:
    print("Getting random sample of left1-wing records")
    left1 = left1.sample(right1.shape[0]) # randomly generate samples from right1 equal to left1's length. (Can be set to random_state=0)

all_data1 = pd.concat([left1, right1]) # combine left1 and right1 datasets
column_names = all_data1.columns.values
all_data1.columns = column_names
all_data1 = all_data1.sample(frac=1).reset_index(drop=True) # randomly shuffle your rows
all_data1['date'] = all_data1['date'].str.replace(',', '')
all_data1.head()
# Out:
# We have 4,304 left1-wing records
# We have 5,780 right1-wing records
# Getting random sample of right1-wing records
#           date                                            article  pole
# 0  2020-02-19   Pete Buttigieg’s Test Has Arrived In this week...     0
# 1  2020-04-14   Gov. Cuomo: Trump Is Not 'King' and Can't Reop...     1
# 2  2020-07-30   Rep. John Lewis Tells Youth to 'Let Freedom Ri...     1
# 3  2020-07-19   How The Black Lives Matter Generation Remember...     0
# 4  2020-04-28   Health Care Workers Stand Up To Anti-Lockdown ...     0

# %%
print("{:,} / {:,} Current Records".format(
    all_data1['pole'].sum(),
    all_data1.shape[0]))

# Only keep the unique rows and their values
all_data1.drop_duplicates("article", keep=False, inplace=True)
print("{:,} Records are unique".format(
    all_data1.shape[0]))

print("{:,} / {:,} Current Records".format(
    all_data1['pole'].sum(),
    all_data1.shape[0]))
# Out:
# 4,304 / 8,608 Current Records
# 8,608 Records are unique
# 4,304 / 8,608 Current Records

# %% [markdown]
# ### 4 sources

# %%
left1 = pd.read_excel("csvs/Huffington.xlsx", 
                  names=["date", "article"])
#left = pd.read_csv('Huffington.csv')
print("We have {:,} left-wing records".format(left1.shape[0]))

for x in range(left1.shape[0]):
    if len(left1['article'][x]) < length_req:
        left1.drop(x, inplace=True)

print("We have {:,} left-wing records > {} characters long".format(left1.shape[0], length_req))

# Only keep the unique article rows and their values
left1.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    left1.shape[0]))

left1['date'] = left1['date'].str.replace(',', '')

left1.head()
# Out:
# We have 4,355 left-wing records
# We have 4,314 left-wing records > 800 characters long
# 4,304 Records are unique
#           date                                            article
# 0  2020-01-01   Elizabeth Warren Rips ‘Fawning, Spineless’ Rep...
# 1  2020-01-01   These Major New Laws Take Effect Today From ma...
# 2  2020-01-01   U.S. To Deploy Hundreds Of Troops To Iraq Afte...
# 3  2020-01-01   Police And Protesters Clash In New Year’s Rall...
# 4  2020-01-01   Trump Shrugs Off Kim Jong Un’s Nuclear Testing...

# %%
left2 = pd.read_excel("csvs/Salon.xlsx", 
                  names=["date", "article"])
#left = pd.read_csv('Huffington.csv')
print("We have {:,} left-wing records".format(left2.shape[0]))

left2['date'].fillna("", inplace=True)
left2['article'].fillna("", inplace=True)

for x in range(left2.shape[0]):
    if len(left2['article'][x]) < length_req:
        left2.drop(x, inplace=True)

print("We have {:,} left-wing records > {} characters long".format(left2.shape[0], length_req))

# Only keep the unique article rows and their values
left2.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    left2.shape[0]))

left2['date'] = left2['date'].str.replace(',', '')

left2.head()
# Out:
# We have 2,303 left-wing records
# We have 2,278 left-wing records > 800 characters long
# 1,987 Records are unique
#           date                                            article
# 0  2020-01-15   Lev Parnas, the indicted associate of former N...
# 1  2020-01-26   President Donald Trump's comments about Thomas...
# 2  2020-05-31   This article originally appeared at Common Dre...
# 3  2020-05-31   Trump admin rush migrant children deportations...
# 4  2020-05-31   The late Gore Vidal once confessed, with chara...

# %%
left_min = [left1.shape[0], left2.shape[0]]
left_min_entries = min(left_min)

left1 = left1.sample(left_min_entries)
left2 = left2.sample(left_min_entries)

print("Huffpost: {} entries".format(left1.shape[0]))
print("Salon: {} entries".format(left2.shape[0]))
# Out:
# Huffpost: 1987 entries
# Salon: 1987 entries

# %%
left = pd.concat([left1, left2])
print("We have {:,} left-wing records".format(left.shape[0]))
# Out:
# We have 3,974 left-wing records

# %%
# Let's see what features we have.
right1 = pd.read_excel("csvs/NewsMax.xlsx",
                     names=["date", "article"])
print("We have {:,} right-wing records".format(right1.shape[0]))

#count = right.shape[0]

for x in range(right1.shape[0]):
    if len(right1['article'][x]) < length_req:
        right1.drop(x, inplace=True)

print("We have {:,} right-wing records > {} characters long".format(right1.shape[0], length_req))

# Only keep the unique rows and their values
right1.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    right1.shape[0]))

right1['date'] = right1['date'].str.replace(',', '')

right1.head()
# Out:
# We have 5,829 right-wing records
# We have 5,637 right-wing records > 800 characters long
# 5,588 Records are unique
#           date                                            article
# 0  2020-01-01   Klobuchar Hits Trump's Golf: 'I Spent 0 Days' ...
# 1  2020-01-01   WashPost: Bloomberg's China Ties Are Conflict ...
# 2  2020-01-01   James Woolsey to Newsmax TV: Target the IRGC N...
# 3  2020-01-01   Report: US Service Members Killed in Afghanist...
# 4  2020-01-01   Bernie Kerik to Newsmax TV: Trump Sends World ...

# %%
right2 = pd.read_excel("csvs/Redstate.xlsx",
                     names=["date", "article"])
print("We have {:,} right-wing records".format(right2.shape[0]))

#count = right.shape[0]

for x in range(right2.shape[0]):
    if len(right2['article'][x]) < length_req:
        right2.drop(x, inplace=True)

print("We have {:,} right-wing records > {} characters long".format(right2.shape[0], length_req))

# Only keep the unique rows and their values
right2.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    right2.shape[0]))

right2['date'] = right2['date'].str.replace(',', '')

right2.head()
# Out:
# We have 2,270 right-wing records
# We have 2,207 right-wing records > 800 characters long
# 2,111 Records are unique
#           date                                            article
# 0  2020-01-15   Even CNN Calls Out Democrats For How They Cele...
# 1  2020-01-26   The Isolation of Connectivity    Image by Thom...
# 2  2020-05-29   Mayor of Minneapolis Lets Rioters Burn Down Po...
# 3  2020-05-29   Watch: CNN Crew Arrested by MN State Police Li...
# 4  2020-05-31   Buffalo Mayor Has Best Response to Rioter Who ...

# %%
right_min = [right1.shape[0], right2.shape[0]]
right_min_entries = min(right_min)

right1 = right1.sample(right_min_entries)
right2 = right2.sample(right_min_entries)

print("NewsMax: {} entries".format(right1.shape[0]))
print("Redstate: {} entries".format(right2.shape[0]))
# Out:
# NewsMax: 2111 entries
# Redstate: 2111 entries

# %%
right = pd.concat([right1, right2])
print("We have {:,} right-wing records".format(right.shape[0]))
# Out:
# We have 4,222 right-wing records

# %%
# Check for null values
right.isnull().sum(axis=0)
# Out:
# date       6
# article    0
# dtype: int64

# %%
left.isnull().sum(axis=0)
# Out:
# date       0
# article    0
# dtype: int64

# %%
# If there were null values, the below will replace them.
left['date'].fillna("", inplace=True)
right['date'].fillna("", inplace=True)
#right['article'].fillna("", inplace=True)
#right.isnull().sum(axis=0)

# %%
# Search for non-null valued rows
# Useful for fixing when data went into three or more columns instead of two in the Excel sheet.
#left[left['date'].notnull()]
#right[right['date'].notnull()]

# Finds all null valued rows
left[~left['date'].notnull()]
#right[~right['date'].notnull()]
# Out:
# Empty DataFrame
# Columns: [date, article]
# Index: []

# %%
left['pole'] = 0  # Make a column 'pole', assign a value of 0 to indicate left articles
print("We have {:,} left-wing records".format(left.shape[0]))
right['pole'] = 1
print("We have {:,} right-wing records".format(right.shape[0]))

if (right.shape[0] > left.shape[0]):
    print("Getting random sample of right-wing records")
    right = right.sample(left.shape[0]) # randomly generate samples from right equal to left's length. (Can be set to random_state=0)
else:
    print("Getting random sample of left-wing records")
    left = left.sample(right.shape[0]) # randomly generate samples from right equal to left's length. (Can be set to random_state=0)

all_data2 = pd.concat([left, right]) # combine left and right datasets
column_names = all_data2.columns.values
all_data2.columns = column_names
all_data2 = all_data2.sample(frac=1).reset_index(drop=True) # randomly shuffle your rows
all_data2['date'] = all_data2['date'].str.replace(',', '')
all_data2.head()
# Out:
# We have 3,974 left-wing records
# We have 4,222 right-wing records
# Getting random sample of right-wing records
#           date                                            article  pole
# 0  2020-03-25   You have to feel sorry for President Trump. He...     0
# 1  2020-06-10   This article originally appeared on AlterNet. ...     0
# 2  2020-03-25   An Arizona man died after ingesting a fish tan...     0
# 3  2020-05-31   Once again, a video was released: George Floyd...     0
# 4  2020-06-30   It seems as if it happened ages ago, but you m...     0

# %%
print("{:,} / {:,} Current Records".format(
    all_data2['pole'].sum(),
    all_data2.shape[0]))

# Only keep the unique rows and their values
all_data2.drop_duplicates("article", keep=False, inplace=True)
print("{:,} Records are unique".format(
    all_data2.shape[0]))

print("{:,} / {:,} Current Records".format(
    all_data2['pole'].sum(),
    all_data2.shape[0]))
# Out:
# 3,974 / 7,948 Current Records
# 7,948 Records are unique
# 3,974 / 7,948 Current Records

# %% [markdown]
# ### 6 sources

# %%
left1 = pd.read_excel("csvs/Huffington.xlsx", 
                  names=["date", "article"])
#left = pd.read_csv('Huffington.csv')
print("We have {:,} left-wing records".format(left1.shape[0]))

for x in range(left1.shape[0]):
    if len(left1['article'][x]) < length_req:
        left1.drop(x, inplace=True)

print("We have {:,} left-wing records > {} characters long".format(left1.shape[0], length_req))

# Only keep the unique article rows and their values
left1.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    left1.shape[0]))

left1['date'] = left1['date'].str.replace(',', '')

left1.head()
# Out:
# We have 4,355 left-wing records
# We have 4,314 left-wing records > 800 characters long
# 4,304 Records are unique
#           date                                            article
# 0  2020-01-01   Elizabeth Warren Rips ‘Fawning, Spineless’ Rep...
# 1  2020-01-01   These Major New Laws Take Effect Today From ma...
# 2  2020-01-01   U.S. To Deploy Hundreds Of Troops To Iraq Afte...
# 3  2020-01-01   Police And Protesters Clash In New Year’s Rall...
# 4  2020-01-01   Trump Shrugs Off Kim Jong Un’s Nuclear Testing...

# %%
left2 = pd.read_excel("csvs/Salon.xlsx", 
                  names=["date", "article"])
#left = pd.read_csv('Huffington.csv')
print("We have {:,} left-wing records".format(left2.shape[0]))

left2['date'].fillna("", inplace=True)
left2['article'].fillna("", inplace=True)

for x in range(left2.shape[0]):
    if len(left2['article'][x]) < length_req:
        left2.drop(x, inplace=True)

print("We have {:,} left-wing records > {} characters long".format(left2.shape[0], length_req))

# Only keep the unique article rows and their values
left2.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    left2.shape[0]))

left2['date'] = left2['date'].str.replace(',', '')

left2.head()
# Out:
# We have 2,303 left-wing records
# We have 2,278 left-wing records > 800 characters long
# 1,987 Records are unique
#           date                                            article
# 0  2020-01-15   Lev Parnas, the indicted associate of former N...
# 1  2020-01-26   President Donald Trump's comments about Thomas...
# 2  2020-05-31   This article originally appeared at Common Dre...
# 3  2020-05-31   Trump admin rush migrant children deportations...
# 4  2020-05-31   The late Gore Vidal once confessed, with chara...

# %%
left3 = pd.read_excel("csvs/Rawstory.xlsx", 
                  names=["date", "article"])
#left = pd.read_csv('Huffington.csv')
print("We have {:,} left-wing records".format(left3.shape[0]))

for x in range(left3.shape[0]):
    if len(left3['article'][x]) < length_req:
        left3.drop(x, inplace=True)

print("We have {:,} left-wing records > {} characters long".format(left3.shape[0], length_req))

# Only keep the unique article rows and their values
left3.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    left3.shape[0]))

left3['date'] = left3['date'].str.replace(',', '')

left3.head()
# Out:
# We have 1,160 left-wing records
# We have 1,159 left-wing records > 800 characters long
# 1,159 Records are unique
#           date                                            article
# 0  2020-01-15   ‘Uninterested in evidence’: Embattled Susan Co...
# 1  2020-02-07   Tornado warning issued for 2 New Jersey counti...
# 2  2020-02-07   Trump official busted for telling ‘blatant lie...
# 3  2020-02-07   Republicans face ‘Electoral College time bomb’...
# 4  2020-02-07   We’re a former coal company and we support gov...

# %%
left_min = [left1.shape[0], left2.shape[0], left3.shape[0]]
left_min_entries = min(left_min)

left1 = left1.sample(left_min_entries)
left2 = left2.sample(left_min_entries)
left3 = left3.sample(left_min_entries)

print("Huffpost: {} entries".format(left1.shape[0]))
print("Salon: {} entries".format(left2.shape[0]))
print("Rawstory: {} entries".format(left3.shape[0]))
# Out:
# Huffpost: 1159 entries
# Salon: 1159 entries
# Rawstory: 1159 entries

# %%
left = pd.concat([left1, left2, left3])
print("We have {:,} left-wing records".format(left.shape[0]))
# Out:
# We have 3,477 left-wing records

# %%
# Let's see what features we have.
right1 = pd.read_excel("csvs/NewsMax.xlsx",
                     names=["date", "article"])
print("We have {:,} right-wing records".format(right1.shape[0]))

#count = right.shape[0]

for x in range(right1.shape[0]):
    if len(right1['article'][x]) < length_req:
        right1.drop(x, inplace=True)

print("We have {:,} right-wing records > {} characters long".format(right1.shape[0], length_req))

# Only keep the unique rows and their values
right1.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    right1.shape[0]))

right1['date'] = right1['date'].str.replace(',', '')

right1.head()
# Out:
# We have 5,829 right-wing records
# We have 5,637 right-wing records > 800 characters long
# 5,588 Records are unique
#           date                                            article
# 0  2020-01-01   Klobuchar Hits Trump's Golf: 'I Spent 0 Days' ...
# 1  2020-01-01   WashPost: Bloomberg's China Ties Are Conflict ...
# 2  2020-01-01   James Woolsey to Newsmax TV: Target the IRGC N...
# 3  2020-01-01   Report: US Service Members Killed in Afghanist...
# 4  2020-01-01   Bernie Kerik to Newsmax TV: Trump Sends World ...

# %%
right2 = pd.read_excel("csvs/Redstate.xlsx",
                     names=["date", "article"])
print("We have {:,} right-wing records".format(right2.shape[0]))

#count = right.shape[0]

for x in range(right2.shape[0]):
    if len(right2['article'][x]) < length_req:
        right2.drop(x, inplace=True)

print("We have {:,} right-wing records > {} characters long".format(right2.shape[0], length_req))

# Only keep the unique rows and their values
right2.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    right2.shape[0]))

right2['date'] = right2['date'].str.replace(',', '')

right2.head()
# Out:
# We have 2,270 right-wing records
# We have 2,207 right-wing records > 800 characters long
# 2,111 Records are unique
#           date                                            article
# 0  2020-01-15   Even CNN Calls Out Democrats For How They Cele...
# 1  2020-01-26   The Isolation of Connectivity    Image by Thom...
# 2  2020-05-29   Mayor of Minneapolis Lets Rioters Burn Down Po...
# 3  2020-05-29   Watch: CNN Crew Arrested by MN State Police Li...
# 4  2020-05-31   Buffalo Mayor Has Best Response to Rioter Who ...

# %%
right3 = pd.read_excel("csvs/WashingtonExaminer.xlsx",
                     names=["date", "article"])
print("We have {:,} right-wing records".format(right3.shape[0]))

#count = right.shape[0]

for x in range(right3.shape[0]):
    if len(right3['article'][x]) < length_req:
        right3.drop(x, inplace=True)

print("We have {:,} right-wing records > {} characters long".format(right3.shape[0], length_req))

# Only keep the unique rows and their values
right3.drop_duplicates("article", keep='first', inplace=True)

print("{:,} Records are unique".format(
    right3.shape[0]))

right3['date'] = right3['date'].str.replace(',', '')

right3.head()
# Out:
# We have 1,117 right-wing records
# We have 1,104 right-wing records > 800 characters long
# 983 Records are unique
#           date                                            article
# 0  2020-01-16   'No one's giggling around here': Democrats def...
# 1  2020-02-19   Bloomberg would sell business and financial in...
# 2  2020-02-19   Uncertainty reigns over Democratic presidentia...
# 3  2020-02-19   Five things to watch in the Nevada Democratic ...
# 4  2020-02-19   'Some guy wearing a dress': Bloomberg once cal...

# %%
right_min = [right1.shape[0], right2.shape[0], right3.shape[0]]
right_min_entries = min(right_min)

right1 = right1.sample(right_min_entries)
right2 = right2.sample(right_min_entries)
right3 = right3.sample(right_min_entries)

print("NewsMax: {} entries".format(right1.shape[0]))
print("Redstate: {} entries".format(right2.shape[0]))
print("WashingtonExaminer: {} entries".format(right3.shape[0]))
# Out:
# NewsMax: 983 entries
# Redstate: 983 entries
# WashingtonExaminer: 983 entries

# %%
right = pd.concat([right1, right2, right3])
print("We have {:,} right-wing records".format(right.shape[0]))
# Out:
# We have 2,949 right-wing records

# %%
# Check for null values
right.isnull().sum(axis=0)
# Out:
# date       4
# article    0
# dtype: int64

# %%
left.isnull().sum(axis=0)
# Out:
# date       9
# article    0
# dtype: int64

# %%
# If there were null values, the below will replace them.
left['date'].fillna("", inplace=True)
right['date'].fillna("", inplace=True)
#right['article'].fillna("", inplace=True)
#right.isnull().sum(axis=0)

# %%
# Search for non-null valued rows
# Useful for fixing when data went into three or more columns instead of two in the Excel sheet.
#left[left['date'].notnull()]
#right[right['date'].notnull()]

# Finds all null valued rows
left[~left['date'].notnull()]
#right[~right['date'].notnull()]
# Out:
# Empty DataFrame
# Columns: [date, article]
# Index: []

# %%
left['pole'] = 0  # Make a column 'pole', assign a value of 0 to indicate left articles
print("We have {:,} left-wing records".format(left.shape[0]))
right['pole'] = 1
print("We have {:,} right-wing records".format(right.shape[0]))

if (right.shape[0] > left.shape[0]):
    print("Getting random sample of right-wing records")
    right = right.sample(left.shape[0]) # randomly generate samples from right equal to left's length. (Can be set to random_state=0)
else:
    print("Getting random sample of left-wing records")
    left = left.sample(right.shape[0]) # randomly generate samples from right equal to left's length. (Can be set to random_state=0)
    
all_data3 = pd.concat([left, right]) # combine left and right datasets
column_names = all_data3.columns.values
all_data3.columns = column_names
all_data3 = all_data3.sample(frac=1).reset_index(drop=True) # randomly shuffle your rows
all_data3['date'] = all_data3['date'].str.replace(',', '')
all_data3.head()
# Out:
# We have 3,477 left-wing records
# We have 2,949 right-wing records
# Getting random sample of left-wing records
#           date                                            article  pole
# 0  2020-07-18   Pelosi Blames Trump for ‘Kidnapping Protesters...     1
# 1  2020-05-11   Remember the Ventilator Crisis? The Press Now ...     1
# 2  2020-07-10   A revolutionized White House briefing should n...     1
# 3  2020-01-22   It’s Not Just Washington State. Iranians Are S...     0
# 4  2020-06-04   AOC Endorses Engel's Challenger in Primary Rep...     1

# %%
print("{:,} / {:,} Current Records".format(
    all_data3['pole'].sum(),
    all_data3.shape[0]))

# Only keep the unique rows and their values
all_data3.drop_duplicates("article", keep=False, inplace=True)
print("{:,} Records are unique".format(
    all_data3.shape[0]))

print("{:,} / {:,} Current Records".format(
    all_data3['pole'].sum(),
    all_data3.shape[0]))
# Out:
# 2,949 / 5,898 Current Records
# 5,898 Records are unique
# 2,949 / 5,898 Current Records

# %%
print("2 sources: {} unique, current records".format(all_data1.shape[0]))
print("4 sources: {} unique, current records".format(all_data2.shape[0]))
print("6 sources: {} unique, current records".format(all_data3.shape[0]))
# Out:
# 2 sources: 8608 unique, current records
# 4 sources: 7948 unique, current records
# 6 sources: 5898 unique, current records

# %% [markdown]
# # Do the below 2 blocks for each run

# %%
# 3 dataframes
all_dataframes = [all_data1, all_data2, all_data3]
all_dataframes[0].head()
# Out:
#           date                                            article  pole
# 0  2020-02-19   Pete Buttigieg’s Test Has Arrived In this week...     0
# 1  2020-04-14   Gov. Cuomo: Trump Is Not 'King' and Can't Reop...     1
# 2  2020-07-30   Rep. John Lewis Tells Youth to 'Let Freedom Ri...     1
# 3  2020-07-19   How The Black Lives Matter Generation Remember...     0
# 4  2020-04-28   Health Care Workers Stand Up To Anti-Lockdown ...     0

# %%
# Remove years and digits from being used as features
def remove_years(text):
    text = re.sub(r"[0-9]{4}", " ", text)
    text = re.sub(r"[0-9]{3}", " ", text)
    text = re.sub(r"[0-9]{2}", " ", text)
    text = re.sub(r"[0-9]{1}", " ", text)
    text = re.sub(r"[0-9]{4}ish", " ", text)
    text = re.sub(r"[0-9]{3}ish", " ", text)
    text = re.sub(r"[0-9]{2}ish", " ", text)
    text = re.sub(r"[0-9]{1}ish", " ", text)
    text = re.sub(r"2020-[0-9]{2}-[0-9]{2}", " ", text)
    return text

# %%
# Proper Noun Removal function
# Do this before lowercasing all text
from nltk.tag import pos_tag

def proper_noun_removal(text):
    tagged_sent = pos_tag(text.split())
    return [w for w, pos in tagged_sent if pos != 'NNP']

# %%
# Lemmatization after Word Tokenization
def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in word_tokenize(text)]

# %%
# Clean each dataframe's data.
for all_data in all_dataframes:
    
    # URL decoding function for decoding any string of html characters...
    all_data['article'] = all_data['article'].astype(str).apply(lambda x: html.unescape(x))
    
    # Store the original comments in a new column
    all_data['unfiltered_articles'] = all_data['article'].values
    all_data['unfiltered_articles_lowercase'] = all_data['article'].values
    all_data['article_PNremoved'] = all_data['article'].values

all_dataframes[0].head()
# Out:
#           date                                            article  pole  \
# 0  2020-02-19   Pete Buttigieg’s Test Has Arrived In this week...     0
# 1  2020-04-14   Gov. Cuomo: Trump Is Not 'King' and Can't Reop...     1
# 2  2020-07-30   Rep. John Lewis Tells Youth to 'Let Freedom Ri...     1
# 3  2020-07-19   How The Black Lives Matter Generation Remember...     0
# 4  2020-04-28   Health Care Workers Stand Up To Anti-Lockdown ...     0
#
#                                  unfiltered_articles  \
# 0  Pete Buttigieg’s Test Has Arrived In this week...
# 1  Gov. Cuomo: Trump Is Not 'King' and Can't Reop...
# 2  Rep. John Lewis Tells Youth to 'Let Freedom Ri...
# 3  How The Black Lives Matter Generation Remember...
# 4  Health Care Workers Stand Up To Anti-Lockdown ...
#
#                        unfiltered_articles_lowercase  \
# 0  Pete Buttigieg’s Test Has Arrived In this week...
# 1  Gov. Cuomo: Trump Is Not 'King' and Can't Reop...
# 2  Rep. John Lewis Tells Youth to 'Let Freedom Ri...
# 3  How The Black Lives Matter Generation Remember...
# 4  Health Care Workers Stand Up To Anti-Lockdown ...
#
#                                    article_PNremoved
# 0  Pete Buttigieg’s Test Has Arrived In this week...
# 1  Gov. Cuomo: Trump Is Not 'King' and Can't Reop...
# 2  Rep. John Lewis Tells Youth to 'Let Freedom Ri...
# 3  How The Black Lives Matter Generation Remember...
# 4  Health Care Workers Stand Up To Anti-Lockdown ...

# %%
# Proper Noun Removal
# Do this before lowercasing all text.
for all_data in all_dataframes:
    all_data['article_PNremoved'] = all_data['article_PNremoved'].apply(proper_noun_removal)

    # Turn the list of tokens back into a sentence
    all_data['article_PNremoved'] = [' '.join(comment) for comment in all_data['article_PNremoved']]

all_dataframes[0].head()
# Out:
#           date                                            article  pole  \
# 0  2020-02-19   Pete Buttigieg’s Test Has Arrived In this week...     0
# 1  2020-04-14   Gov. Cuomo: Trump Is Not 'King' and Can't Reop...     1
# 2  2020-07-30   Rep. John Lewis Tells Youth to 'Let Freedom Ri...     1
# 3  2020-07-19   How The Black Lives Matter Generation Remember...     0
# 4  2020-04-28   Health Care Workers Stand Up To Anti-Lockdown ...     0
#
#                                  unfiltered_articles  \
# 0  Pete Buttigieg’s Test Has Arrived In this week...
# 1  Gov. Cuomo: Trump Is Not 'King' and Can't Reop...
# 2  Rep. John Lewis Tells Youth to 'Let Freedom Ri...
# 3  How The Black Lives Matter Generation Remember...
# 4  Health Care Workers Stand Up To Anti-Lockdown ...
#
#                        unfiltered_articles_lowercase  \
# 0  Pete Buttigieg’s Test Has Arrived In this week...
# 1  Gov. Cuomo: Trump Is Not 'King' and Can't Reop...
# 2  Rep. John Lewis Tells Youth to 'Let Freedom Ri...
# 3  How The Black Lives Matter Generation Remember...
# 4  Health Care Workers Stand Up To Anti-Lockdown ...
#
#                                    article_PNremoved
# 0  Arrived In this week’s caucuses, the Democrati...
# 1  Is Not 'King' and States warned not to push re...
# 2  to 'Let in before civil rights icon died, he w...
# 3  How The Lives the civil rights icon who some c...
# 4  Workers To In putting me and my family at risk...

# %%
# Clean each dataframe's data
removal = ["article", "article_PNremoved"]

for all_data in all_dataframes:
    for column in removal:
        # Clean the text
        # The apostrophes here are very specific.
        # The regular ' will not work from keyboard.
        # You have to use print(all_data.head()) and copy and paste that apostrophe into the str.replace()
        all_data[column] = all_data[column].str.lower()
        all_data[column] = all_data[column].str.replace(r"u.s.", "united states")
        all_data[column] = all_data[column].str.replace(r"what’s", "what is")
        all_data[column] = all_data[column].str.replace(r"’s", " ")
        all_data[column] = all_data[column].str.replace(r"’ve", "have")
        all_data[column] = all_data[column].str.replace(r"’re", "are")
        all_data[column] = all_data[column].str.replace(r"’ll", "will")
        all_data[column] = all_data[column].str.replace(r"can’t", "can not")
        all_data[column] = all_data[column].str.replace(r"aren’t", "are not")
        all_data[column] = all_data[column].str.replace(r"couldn’t", "could not")
        all_data[column] = all_data[column].str.replace(r"didn’t", "did not")
        all_data[column] = all_data[column].str.replace(r"doesn’t", "does not")
        all_data[column] = all_data[column].str.replace(r"don’t", "do not")
        all_data[column] = all_data[column].str.replace(r"hadn’t", "had not")
        all_data[column] = all_data[column].str.replace(r"hasn’t", "has not")
        all_data[column] = all_data[column].str.replace(r"haven’t", "have not")
        all_data[column] = all_data[column].str.replace(r"isn’t", "is not")
        all_data[column] = all_data[column].str.replace(r"shouldn’t", "should not")
        all_data[column] = all_data[column].str.replace(r"wasn’t", "was not")
        all_data[column] = all_data[column].str.replace(r"weren’t", "were not")
        all_data[column] = all_data[column].str.replace(r"won’t", "will not")
        all_data[column] = all_data[column].str.replace(r"wouldn’t", "would not")
        all_data[column] = all_data[column].str.replace(r"mustn’t", "must not")
        all_data[column] = all_data[column].str.replace(r"i’m", "i am")

        # As are these apostrophes...
        all_data[column] = all_data[column].str.replace(r"what's", "what is")
        all_data[column] = all_data[column].str.replace(r"'s", " ")
        all_data[column] = all_data[column].str.replace(r"'ve", "have")
        all_data[column] = all_data[column].str.replace(r"'re", "are")
        all_data[column] = all_data[column].str.replace(r"'ll", "will")
        all_data[column] = all_data[column].str.replace(r"can't", "can not")
        all_data[column] = all_data[column].str.replace(r"aren't", "are not")
        all_data[column] = all_data[column].str.replace(r"couldn't", "could not")
        all_data[column] = all_data[column].str.replace(r"didn't", "did not")
        all_data[column] = all_data[column].str.replace(r"doesn't", "does not")
        all_data[column] = all_data[column].str.replace(r"don't", "do not")
        all_data[column] = all_data[column].str.replace(r"hadn't", "had not")
        all_data[column] = all_data[column].str.replace(r"hasn't", "has not")
        all_data[column] = all_data[column].str.replace(r"haven't", "have not")
        all_data[column] = all_data[column].str.replace(r"isn't", "is not")
        all_data[column] = all_data[column].str.replace(r"shouldn't", "should not")
        all_data[column] = all_data[column].str.replace(r"wasn't", "was not")
        all_data[column] = all_data[column].str.replace(r"weren't", "were not")
        all_data[column] = all_data[column].str.replace(r"won't", "will not")
        all_data[column] = all_data[column].str.replace(r"wouldn't", "would not")
        all_data[column] = all_data[column].str.replace(r"mustn't", "must not")
        all_data[column] = all_data[column].str.replace(r"i'm", "i am")
        #print(all_data.head())

        # Custom word removal - these appear too frequently and do not help with generalization.
        custom = {"donald j trump", "donald j. trump", "donald john trump", 'newsmax', 'redstate', 'washingtonexaminer', 'washington examiner', 
                  "huffpost", 'salon', 'rawstory', 'raw story',
                  "___", "donald trump", "trump", "pelosi"}

        # Did not work
        #for word in custom:
        #    all_data["article"]= all_data["article"].replace(word, " ") 

        # Did not work
        #all_data[column] = all_data[column].apply(lambda x: ' '.join([word for word in x.split() if word not in (custom)]))

        # Did work
        #def customWord(text):
        #    custom = {"huffpost", "newsmax"}
        #    return text.replace("huffpost", " ") 

        for word in custom:
            all_data[column] = all_data[column].apply(lambda x: x.replace(word, " "))

        # Check to see the words were replaced
        #print(all_data[all_data[column].str.contains("newsmax")])

        # Remove years and digits from being used as features
        all_data[column] = all_data[column].apply(lambda x: remove_years(x))
        #print(all_data.head())

        # Punctuation removal - CountVectorizer() does this for you
        #punctuation = {'.', ':', ';', "\'", '\"', '!', '?', "\’", '(', ')', '-'}

        #print(all_data[all_data[column].str.contains("19")])
        
all_dataframes[0].head()
# Out:
#           date                                            article  pole  \
# 0  2020-02-19   pete buttigieg  test has arrived in this week ...     0
# 1  2020-04-14   gov. cuomo:   is not 'king' and can not reopen...     1
# 2  2020-07-30   rep. john lewis tells youth to 'let freedom ri...     1
# 3  2020-07-19   how the black lives matter generation remember...     0
# 4  2020-04-28   health care workers stand up to anti-lockdown ...     0
#
#                                  unfiltered_articles  \
# 0  Pete Buttigieg’s Test Has Arrived In this week...
# 1  Gov. Cuomo: Trump Is Not 'King' and Can't Reop...
# 2  Rep. John Lewis Tells Youth to 'Let Freedom Ri...
# 3  How The Black Lives Matter Generation Remember...
# 4  Health Care Workers Stand Up To Anti-Lockdown ...
#
#                        unfiltered_articles_lowercase  \
# 0  Pete Buttigieg’s Test Has Arrived In this week...
# 1  Gov. Cuomo: Trump Is Not 'King' and Can't Reop...
# 2  Rep. John Lewis Tells Youth to 'Let Freedom Ri...
# 3  How The Black Lives Matter Generation Remember...
# 4  Health Care Workers Stand Up To Anti-Lockdown ...
#
#                                    article_PNremoved
# 0  arrived in this week  caucuses, the democratic...
# 1  is not 'king' and states warned not to push re...
# 2  to 'let in before civil rights icon died, he w...
# 3  how the lives the civil rights icon who some c...
# 4  workers to in putting me and my family at risk...

# %%
# CountVectorizers for onegram, bigram, trigram
# Does not work as intended
#max_df_value = 0.75
#min_df_value = 4

#count_vect1 = CountVectorizer(min_df = min_df_value, max_df = max_df_value, stop_words='english', max_features=5000)
#count_vect2 = CountVectorizer(min_df = min_df_value, max_df = max_df_value, stop_words='english', ngram_range=(1, 2), max_features=5000)
#count_vect3 = CountVectorizer(min_df = min_df_value, max_df = max_df_value, stop_words='english', ngram_range=(1, 3), max_features=5000)

#count_vectorizers = [count_vect1, count_vect2, count_vect3]

# %%
# Shows you the most frequently occurring words seen in text labelled as left or right
# This works on the most recent clf, but should relatively represent the same features used by each classifier
# so long as the parameters for min_df and max_df for each classifier are the same
def show_most_informative_features(vectorizer, clf, n=20):
    top_features = []
    right = []
    left = []
    feature_names = vectorizer.get_feature_names() # Get all the feature names that CountVectorizer() is using
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names)) # Put all feature names with their weights. Sort.
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1]) 
    print("\t\t%-15s\t\t\t%-15s" % ('Left', 'Right'))
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print("\t%.4f\t%-15s\t\t%.4f\t%-15s" % (coef_1, fn_1, coef_2, fn_2))    
        top_features.append([fn_1, coef_1, fn_2, coef_2])
        right.append([coef_2, fn_2])
        left.append([coef_1, fn_1])
    for x in range(len(left)):
        right.append([left[x][0], left[x][1]])
    print()
    return top_features, right

# %%
# Different Parameters
params = ['h_and_n_onegram_sr_nol_nopr', 'h_and_n_bigram_sr_nol_nopr', 'h_and_n_trigram_sr_nol_nopr', 
          'h_and_n_onegram_sr_nol_pr', 'h_and_n_bigram_sr_nol_pr', 'h_and_n_trigram_sr_nol_pr',
          'hs_and_nr_onegram_sr_nol_nopr', 'hs_and_nr_bigram_sr_nol_nopr', 'hs_and_nr_trigram_sr_nol_nopr',
          'hs_and_nr_onegram_sr_nol_pr', 'hs_and_nr_bigram_sr_nol_pr', 'hs_and_nr_trigram_sr_nol_pr',
          'hsr_and_nrw_onegram_sr_nol_nopr', 'hsr_and_nrw_bigram_sr_nol_nopr', 'hsr_and_nrw_trigram_sr_nol_nopr',
          'hsr_and_nrw_onegram_sr_nol_pr', 'hsr_and_nrw_bigram_sr_nol_pr', 'hsr_and_nrw_trigram_sr_nol_pr',
          'h_and_n_onegram_sr_l_nopr', 'h_and_n_bigram_sr_l_nopr', 'h_and_n_trigram_sr_l_nopr', 
          'h_and_n_onegram_sr_l_pr', 'h_and_n_bigram_sr_l_pr', 'h_and_n_trigram_sr_l_pr',
          'hs_and_nr_onegram_sr_l_nopr', 'hs_and_nr_bigram_sr_l_nopr', 'hs_and_nr_trigram_sr_l_nopr',
          'hs_and_nr_onegram_sr_l_pr', 'hs_and_nr_bigram_sr_l_pr', 'hs_and_nr_trigram_sr_l_pr',
          'hsr_and_nrw_onegram_sr_l_nopr', 'hsr_and_nrw_bigram_sr_l_nopr', 'hsr_and_nrw_trigram_sr_l_nopr',
          'hsr_and_nrw_onegram_sr_l_pr', 'hsr_and_nrw_bigram_sr_l_pr', 'hsr_and_nrw_trigram_sr_l_pr']

# %%
top_features_dict = {}
top_features_arr = []
number_count_vectorizers = 3
count = 0

for all_data in all_dataframes:
    for column in removal:
        
        if (count > 17):
            # Lemmatization after Word Tokenization
            lemmatizer = WordNetLemmatizer()
            all_data[column] = all_data[column].apply(lemmatize_text)

            # Turn the list of tokens back into a sentence
            all_data[column] = [' '.join(comment) for comment in all_data[column]]
        
        for x in range(number_count_vectorizers):

            # Randomly shuffle the rows before the split each time
            all_data = all_data.sample(frac=1)

            # Try an 80/20 train/test split
            train, test = train_test_split(all_data, test_size=0.2)

            if (x == 0):
                count_vect = CountVectorizer(min_df = 4, max_df = .75, stop_words='english', max_features=5000)
            elif (x == 1):
                count_vect = CountVectorizer(min_df = 4, max_df = .75, stop_words='english', ngram_range=(1, 2), max_features=5000)
            else:
                count_vect = CountVectorizer(min_df = 4, max_df = .75, stop_words='english', ngram_range=(1, 3), max_features=5000)
           # 
           # X_train_counts = count_vect.fit_transform(train[column])
           # X_train_counts.shape

           # tfidf_transformer = TfidfTransformer()
           # X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
           # X_train_tfidf.shape

           # clf = SGDClassifier().fit(X_train_tfidf, train.pole)
            
            clf = Pipeline([('vect', count_vect),
                                ('tfidf', TfidfTransformer()),
                                ('clf', LinearSVC(random_state=0)),
            ])
            
            clf = clf.fit(train.article, train.pole)
            
            # Accuracy
            predicted = clf.predict(test.unfiltered_articles)
            results = metrics.confusion_matrix(test.pole, predicted)
            accuracy = metrics.accuracy_score(test.pole, predicted)
            print(params[count])
            print("LinearSVC Accuracy Score: ", accuracy)

            # Grab and Print the top features for each different set of parameters
            #top_features = show_most_informative_features(count_vect, clf, 40)
            top_features_list, top_features = show_most_informative_features(count_vect, clf.named_steps['clf'], 40)
            
            # Put them in a dictionary
            top_features_dict[params[count]] = top_features_list
            
            # Put the top features in an array
            for x in range(len(top_features)):
                top_features_arr.append(top_features[x])
            
            # Let's save our model
            joblib.dump(clf, 'SVC/' + params[count] + ".pkl")

            count += 1
# Out:
# h_and_n_onegram_sr_nol_nopr
# LinearSVC Accuracy Score:  0.8281068524970964
# 		Left           			Right
# 	-4.2589	ap             		3.6417	reports
# 	-3.6140	check          		3.1057	healthcare
# 	-3.1920	reportedly     		2.7406	democrat
# 	-2.9758	users          		2.6270	dems
# 	-2.8478	repeatedly     		2.4777	hill
# 	-2.7988	covid          		2.3439	according
# 	-2.7550	host           		2.1988	ny
# 	-2.7085	claimed        		1.8808	dem
# 	-2.4370	suggested      		1.7949	politico
# 	-2.3275	month          		1.7941	riots
# 	-2.2959	warned         		1.7755	aoc
# 	-2.2778	calif          		1.7290	fall
# 	-2.1605	amid           		1.6489	gizzi
# 	-2.1261	progressive    		1.5318	posted
# 	-2.1192	yougov         		1.5150	wh
# 	-2.0877	correction     		1.4964	ch
# 	-2.0416	apparently     		1.4933	discunited
# 	-2.0367	later          		1.4687	criticism
# 	-2.0324	democratic     		1.4346	dc
# 	-2.0317	reporter       		1.4313	tweeted
# 	-2.0003	zelensky       		1.4221	think
# 	-1.9761	editorial      		1.3938	mike
# 	-1.9433	editing        		1.3822	cbs
# 	-1.9429	asked          		1.3817	chairman
# 	-1.8805	disease        		1.3784	order
# 	-1.8670	spokesperson   		1.3436	virus
# 	-1.8660	explained      		1.3295	newsroom
# 	-1.8617	ky             		1.3240	civilian
# 	-1.8609	live           		1.3209	blasts
# 	-1.8417	previously     		1.3027	nov
# 	-1.8386	urged          		1.2846	rejecting
# 	-1.8314	anti           		1.2764	bernie
# 	-1.8254	assassination  		1.2535	nbc
# 	-1.8177	confirmed      		1.2415	liberal
# 	-1.8056	meant          		1.2314	commented
# 	-1.7955	guide          		1.2250	gen
# 	-1.7284	despite        		1.2234	acquitted
# 	-1.7165	believed       		1.2169	brought
# 	-1.7130	twitter        		1.2112	iwill
# 	-1.6899	year           		1.2024	axios
#
# h_and_n_bigram_sr_nol_nopr
# LinearSVC Accuracy Score:  0.8408826945412311
# 		Left           			Right
# 	-4.6927	ap             		3.8162	reports
# 	-3.8833	check          		3.1383	healthcare
# 	-3.7725	washington ap  		2.5526	dems
# 	-2.9534	reportedly     		2.3685	democrat
# 	-2.7630	covid          		2.2386	hill
# 	-2.7285	claimed        		2.2278	hill reported
# 	-2.6780	warned         		2.0826	according
# 	-2.6248	suggested      		2.0460	ny
# 	-2.6188	host           		1.9017	told fox
# 	-2.5582	twitter users  		1.8995	fall
# 	-2.4099	repeatedly     		1.8461	politico
# 	-2.3606	progressive    		1.8331	news reports
# 	-2.3195	reporter       		1.6740	news outlet
# 	-2.1666	yougov         		1.6300	according hill
# 	-2.1433	amid           		1.6094	mike bloomberg
# 	-2.1283	apparently     		1.5904	riots
# 	-2.1176	correction     		1.5835	tweeted
# 	-1.8975	confirmed      		1.5715	aoc
# 	-1.8930	month          		1.4896	police custody
# 	-1.8525	guide coronavirus		1.4581	schumer
# 	-1.8441	major          		1.4520	news fox
# 	-1.8165	read           		1.4411	comments came
# 	-1.8064	calif          		1.4359	chairman
# 	-1.8035	assassination  		1.4291	democratic gov
# 	-1.7850	zelensky       		1.4275	dc
# 	-1.7612	explained      		1.4257	said said
# 	-1.7535	analyst        		1.4179	liberal
# 	-1.7120	disease caused 		1.4056	republican president
# 	-1.6946	announce       		1.3974	activities
# 	-1.6854	covid disease  		1.3897	strong
# 	-1.6627	meant          		1.3846	democrats
# 	-1.6507	latest         		1.3495	global coronavirus
# 	-1.6192	later          		1.3317	refusal
# 	-1.6115	means          		1.3316	built
# 	-1.6092	right wing     		1.3284	opinion piece
# 	-1.6069	updated        		1.3251	rights reserved
# 	-1.6050	anti racism    		1.3185	cnbc
# 	-1.5973	previously     		1.3090	fox friends
# 	-1.5887	anti           		1.2720	nov
# 	-1.5853	contributed reporting		1.2706	attend
#
# h_and_n_trigram_sr_nol_nopr
# LinearSVC Accuracy Score:  0.8385598141695703
# 		Left           			Right
# 	-4.4727	ap             		3.4791	reports
# 	-3.8678	washington ap  		3.2264	hill
# 	-3.4050	check          		3.2214	healthcare
# 	-3.1781	reportedly     		2.8111	dems
# 	-3.0249	covid          		2.7693	democrat
# 	-2.8206	suggested      		2.2142	ny
# 	-2.7024	claimed        		2.1237	hill reported
# 	-2.6395	warned         		2.0049	politico
# 	-2.6361	repeatedly     		1.9327	according
# 	-2.5807	host           		1.7809	fall
# 	-2.4625	progressive    		1.6575	news reports
# 	-2.3489	yougov         		1.5979	news outlet
# 	-2.3464	twitter users  		1.5652	tweeted
# 	-2.2423	zelensky       		1.5254	mike bloomberg
# 	-2.2129	month          		1.5033	according hill
# 	-2.0641	users          		1.5016	axios
# 	-2.0468	rival          		1.4971	virus
# 	-2.0425	later          		1.4446	police custody
# 	-2.0269	live           		1.4285	schumer
# 	-1.9708	correction     		1.4140	cbs news
# 	-1.9513	reporter       		1.4067	told fox
# 	-1.9273	reporting      		1.3965	intends
# 	-1.8962	amid           		1.3938	riots
# 	-1.8883	apparently     		1.3929	democrats
# 	-1.7959	guide coronavirus		1.3871	news fox friends
# 	-1.7942	assassination  		1.3488	probe
# 	-1.7825	editorial      		1.3405	global coronavirus
# 	-1.7777	major          		1.3344	gen
# 	-1.7630	confirmed      		1.3156	posts
# 	-1.7556	twitter        		1.3039	john
# 	-1.7246	previously     		1.2822	cbs
# 	-1.7060	image          		1.2746	global coronavirus pandemic
# 	-1.6801	initially      		1.2686	socialist
# 	-1.6783	earlier        		1.2520	integrity
# 	-1.6114	reelection     		1.2498	favored
# 	-1.6112	check clip     		1.2297	comments came
# 	-1.6096	noting         		1.2295	vp
# 	-1.6047	downplayed     		1.2285	chairman
# 	-1.5808	right wing     		1.2162	brought
# 	-1.5805	guide          		1.1989	iwill
#
# h_and_n_onegram_sr_nol_pr
# LinearSVC Accuracy Score:  0.8234610917537747
# 		Left           			Right
# 	-4.0920	ap             		3.8231	reports
# 	-3.5146	check          		3.1200	healthcare
# 	-3.1725	reportedly     		2.9691	dems
# 	-3.1095	users          		2.7436	democrat
# 	-2.9705	repeatedly     		2.5275	hill
# 	-2.9292	covid          		2.3425	ny
# 	-2.6995	warned         		2.2627	according
# 	-2.6897	claimed        		2.0217	mike
# 	-2.6685	apparently     		1.8830	riots
# 	-2.6188	host           		1.8041	dem
# 	-2.5700	yougov         		1.7665	wh
# 	-2.3830	suggested      		1.6876	politico
# 	-2.2575	amid           		1.6123	aoc
# 	-2.1204	editorial      		1.6068	gizzi
# 	-2.0955	zelensky       		1.5760	tweeted
# 	-2.0888	guide          		1.5611	think
# 	-2.0718	calif          		1.5512	civilian
# 	-2.0221	correction     		1.5119	ch
# 	-2.0030	asked          		1.5103	fall
# 	-1.9488	month          		1.5037	cbs
# 	-1.9295	progressive    		1.4125	want
# 	-1.9088	reporter       		1.3514	axios
# 	-1.8878	announce       		1.3507	iwill
# 	-1.8751	racist         		1.3480	tech
# 	-1.8541	live           		1.3391	criticism
# 	-1.8401	meant          		1.3348	african
# 	-1.8320	care           		1.3300	virus
# 	-1.7965	previously     		1.3295	strong
# 	-1.7943	urged          		1.3293	commented
# 	-1.7797	updated        		1.3202	socialist
# 	-1.7785	reelection     		1.3184	nov
# 	-1.7481	statement      		1.2602	order
# 	-1.7469	disease        		1.2512	criminals
# 	-1.7115	democratic     		1.2487	morning
# 	-1.6830	ky             		1.2397	rejecting
# 	-1.6710	old            		1.2337	holding
# 	-1.6695	confirmed      		1.2238	hillary
# 	-1.6644	vice           		1.2139	illegal
# 	-1.6614	read           		1.1948	newsroom
# 	-1.6450	latest         		1.1832	st
# h_and_n_bigram_sr_nol_pr
# LinearSVC Accuracy Score:  0.8461091753774681
# 		Left           			Right
# 	-4.1357	ap             		3.8107	reports
# 	-3.8701	washington ap  		3.1273	healthcare
# 	-3.2671	check          		2.8195	dems
# 	-2.9471	reportedly     		2.8174	hill
# 	-2.8548	covid          		2.5412	democrat
# 	-2.7532	claimed        		2.1770	ny
# 	-2.5316	twitter users  		2.0869	according
# 	-2.5313	repeatedly     		1.9111	hill reported
# 	-2.5261	suggested      		1.8489	politico
# 	-2.4267	warned         		1.6873	told fox
# 	-2.3984	progressive    		1.6696	global coronavirus
# 	-2.3257	host           		1.6549	riots
# 	-2.2890	users          		1.5803	tweeted
# 	-2.2441	zelensky       		1.5792	news outlet
# 	-2.2105	correction     		1.5688	mike bloomberg
# 	-2.1639	yougov         		1.5500	according hill
# 	-2.1342	month          		1.5282	virus
# 	-1.9022	apparently     		1.5229	republican president
# 	-1.8665	reporter       		1.5053	police custody
# 	-1.8511	later          		1.4904	posts
# 	-1.8326	reelection     		1.4889	fall
# 	-1.8288	sunited        		1.4537	intends
# 	-1.8273	footage        		1.4397	aoc
# 	-1.8239	previously     		1.3796	fox friends
# 	-1.8021	editorial      		1.3760	july
# 	-1.7877	check clip     		1.3698	integrity
# 	-1.7722	amid           		1.3681	axios
# 	-1.7639	reporting      		1.3621	news reports
# 	-1.7290	attacked       		1.3613	news fox
# 	-1.7245	contributed    		1.3291	journal
# 	-1.7234	read           		1.3268	schumer
# 	-1.7162	guide          		1.3184	iwill
# 	-1.7024	twitter        		1.2905	chairman
# 	-1.6948	latest         		1.2880	nazi
# 	-1.6720	democratic     		1.2866	percent
# 	-1.6510	guide coronavirus		1.2837	sought
# 	-1.6424	scandal        		1.2804	said friday
# 	-1.6313	claim          		1.2721	rights reserved
# 	-1.6206	means          		1.2611	cbs news
# 	-1.6121	currently      		1.2206	criminals
#
# h_and_n_trigram_sr_nol_pr
# LinearSVC Accuracy Score:  0.8437862950058072
# 		Left           			Right
# 	-4.2025	ap             		3.9325	reports
# 	-3.8053	washington ap  		3.2245	healthcare
# 	-3.7225	check          		2.5450	dems
# 	-2.9190	claimed        		2.3307	democrat
# 	-2.9094	suggested      		2.1536	according
# 	-2.7966	reportedly     		2.0762	hill
# 	-2.6548	covid          		1.9827	ny
# 	-2.5927	host           		1.8326	hill reported
# 	-2.5245	twitter users  		1.7813	politico
# 	-2.3107	yougov         		1.7436	news outlet
# 	-2.2965	previously     		1.7401	news reports
# 	-2.2774	progressive    		1.6665	police custody
# 	-2.2157	repeatedly     		1.6567	fall
# 	-2.1919	warned         		1.6340	chairman
# 	-2.1559	asked          		1.6319	mike bloomberg
# 	-2.1062	month          		1.6298	riots
# 	-2.0632	zelensky       		1.6011	morning
# 	-1.9801	reporter       		1.5714	aoc
# 	-1.9465	guide coronavirus		1.4990	gen
# 	-1.9364	amid           		1.4952	said friday
# 	-1.9228	apparently     		1.4866	according hill
# 	-1.9163	correction     		1.4812	schumer
# 	-1.8666	offered        		1.4760	tweeted
# 	-1.8611	users          		1.4733	liberal
# 	-1.8567	old            		1.4337	iwill
# 	-1.8187	analyst        		1.4135	told fox
# 	-1.8100	video          		1.3886	global coronavirus pandemic
# 	-1.7408	later          		1.3847	global coronavirus
# 	-1.7253	population     		1.3203	nov
# 	-1.7093	guide          		1.2974	cnbc
# 	-1.6937	democratic     		1.2971	axios
# 	-1.6900	check clip     		1.2968	fox friends
# 	-1.6877	reelection     		1.2952	journal
# 	-1.6821	editorial      		1.2788	july
# 	-1.6686	spokesperson   		1.2758	discunited
# 	-1.6562	scandal        		1.2744	virus
# 	-1.6494	shared         		1.2739	meet
# 	-1.6257	means          		1.2698	obama administration
# 	-1.6154	basic          		1.2552	criminals
# 	-1.6040	calif          		1.2552	senior adviser
#
# hs_and_nr_onegram_sr_nol_nopr
# LinearSVC Accuracy Score:  0.879874213836478
# 		Left           			Right
# 	-5.3140	originally     		2.9173	alex
# 	-5.1704	appeared       		2.8336	reports
# 	-3.5590	article        		2.6764	dems
# 	-2.5798	writer         		2.5870	healthcare
# 	-2.5484	host           		2.4963	democrat
# 	-2.4182	warned         		2.4557	hill
# 	-2.3701	check          		2.2398	wuhan
# 	-2.1757	reportedly     		1.8511	ny
# 	-2.1482	claimed        		1.7601	dem
# 	-2.1042	alternet       		1.7590	rioters
# 	-2.0950	month          		1.7312	communist
# 	-2.0731	critics        		1.5477	laar
# 	-2.0513	democratic     		1.5462	pieces
# 	-1.9822	disease        		1.5294	aoc
# 	-1.9342	baltimore      		1.5059	leftist
# 	-1.8502	repeatedly     		1.4957	ca
# 	-1.8309	ky             		1.4768	democrats
# 	-1.8237	yougov         		1.4740	left
# 	-1.7873	sponsored      		1.4578	illegal
# 	-1.7747	care           		1.4575	cancel
# 	-1.7596	clip           		1.4215	tries
# 	-1.7380	widely         		1.3972	total
# 	-1.6860	suggested      		1.3888	place
# 	-1.6770	igor           		1.3745	parker
# 	-1.6612	herald         		1.3675	mob
# 	-1.6558	asked          		1.3535	riots
# 	-1.6419	week           		1.3501	yesterday
# 	-1.6340	reporter       		1.3293	joe
# 	-1.6219	cookies        		1.3234	discunited
# 	-1.5785	covid          		1.3178	provide
# 	-1.5218	footage        		1.2864	native
# 	-1.5037	editorial      		1.2810	axios
# 	-1.4805	argued         		1.2403	woke
# 	-1.4732	described      		1.2298	mexico
# 	-1.4725	public         		1.2152	ferrer
# 	-1.4544	spread         		1.2151	media
# 	-1.4400	users          		1.2142	socialist
# 	-1.4149	complained     		1.1958	stressed
# 	-1.4120	urged          		1.1956	looking
# 	-1.3766	wednesday      		1.1931	tells
#
# hs_and_nr_bigram_sr_nol_nopr
# LinearSVC Accuracy Score:  0.8823899371069183
# 		Left           			Right
# 	-4.3373	article originally		3.0971	reports
# 	-4.1477	originally appeared		2.6618	democrat
# 	-3.5575	originally     		2.6195	dems
# 	-3.1567	appeared       		2.3039	ap photo
# 	-2.6703	check          		2.2654	hill
# 	-2.4908	host           		2.2217	healthcare
# 	-2.4619	article        		2.1467	alex
# 	-2.2706	writer         		1.8721	told fox
# 	-2.2068	yougov         		1.8699	rioters
# 	-2.1126	month          		1.8659	democrats
# 	-2.0908	repeatedly     		1.8591	dem
# 	-2.0125	democratic     		1.6642	aoc
# 	-1.9830	argued         		1.6346	wuhan
# 	-1.9814	claimed        		1.5957	tries
# 	-1.9585	warned         		1.5497	today
# 	-1.7906	covid          		1.5437	ny
# 	-1.7863	week           		1.4485	communist
# 	-1.7301	sponsored      		1.4163	mob
# 	-1.6452	editorial      		1.3975	left
# 	-1.6129	alternet       		1.3964	ca
# 	-1.6092	appeared alternet		1.3798	illegal
# 	-1.6045	reportedly     		1.3790	luxury
# 	-1.5780	right wing     		1.3635	woke
# 	-1.5646	staff writer   		1.3548	according
# 	-1.5383	reporter       		1.3363	cancel
# 	-1.5379	disease        		1.3087	leftist
# 	-1.5294	zelensky       		1.3049	discunited
# 	-1.5028	complained     		1.3015	yesterday
# 	-1.4986	critics        		1.2945	related
# 	-1.4736	clip           		1.2559	tells
# 	-1.4701	news host      		1.2543	dc
# 	-1.4447	public         		1.2487	seattle
# 	-1.4395	demanded       		1.2407	ag
# 	-1.4339	spread         		1.2358	important
# 	-1.4291	work appeared  		1.2349	tweet
# 	-1.4168	widely         		1.2295	crazy
# 	-1.4139	shared         		1.2204	socialist
# 	-1.3786	meant          		1.2147	gen
# 	-1.3613	image          		1.2112	riots
# 	-1.3547	contributed    		1.1999	schumer
# hs_and_nr_trigram_sr_nol_nopr
# LinearSVC Accuracy Score:  0.8830188679245283
# 		Left           			Right
# 	-3.6210	article originally		2.8114	democrat
# 	-3.4356	originally appeared		2.7563	hill
# 	-3.3641	article originally appeared		2.6519	reports
# 	-3.1599	appeared       		2.5951	dems
# 	-2.9207	originally     		2.4622	ap photo
# 	-2.5547	writer         		2.1758	healthcare
# 	-2.4598	check          		2.1250	ny
# 	-2.3934	repeatedly     		1.8506	wuhan
# 	-2.3292	month          		1.7892	rioters
# 	-2.1889	democratic     		1.6649	alex
# 	-2.1546	host           		1.5476	told fox
# 	-2.1407	yougov         		1.5455	axios
# 	-2.1367	reportedly     		1.5035	ca
# 	-1.9626	users          		1.4994	communist
# 	-1.9497	ap             		1.4791	riots
# 	-1.9294	sponsored      		1.4781	leftist
# 	-1.8843	image          		1.4644	woke
# 	-1.8286	disease        		1.4312	john
# 	-1.8054	article        		1.4191	luxury
# 	-1.7912	claimed        		1.4057	mob
# 	-1.7303	guide          		1.4032	cancel
# 	-1.7251	argued         		1.3971	mike bloomberg
# 	-1.6765	warned         		1.3956	schumer
# 	-1.6723	critics        		1.3705	tries
# 	-1.6396	widely         		1.3612	aoc
# 	-1.6270	showed         		1.3257	dc
# 	-1.5742	middle         		1.3209	place
# 	-1.5595	battle         		1.3078	today
# 	-1.5576	demanded       		1.3065	democrats
# 	-1.5428	clip           		1.2739	yesterday
# 	-1.5361	footage        		1.2651	thought
# 	-1.5282	asked          		1.2459	hollywood
# 	-1.5207	editorial      		1.2431	socialist
# 	-1.4991	photo op       		1.2021	looking
# 	-1.4312	fans           		1.2001	express
# 	-1.4294	week           		1.1995	hall
# 	-1.4293	lgbtq          		1.1873	establishment
# 	-1.4182	told           		1.1646	gen
# 	-1.4093	covid disease  		1.1645	cnbc
# 	-1.4030	coronavirus pandemic		1.1613	non
#
# hs_and_nr_onegram_sr_nol_pr
# LinearSVC Accuracy Score:  0.8635220125786164
# 		Left           			Right
# 	-5.5120	originally     		3.0176	hill
# 	-4.4503	appeared       		2.8517	dems
# 	-3.1149	article        		2.8093	reports
# 	-2.8868	writer         		2.7949	alex
# 	-2.8851	host           		2.5309	democrat
# 	-2.8631	month          		2.3039	wuhan
# 	-2.3425	warned         		2.2285	healthcare
# 	-2.2153	check          		1.9074	dem
# 	-2.2057	alternet       		1.7356	left
# 	-2.1492	argued         		1.6892	ny
# 	-2.1040	sponsored      		1.6369	woke
# 	-2.0891	repeatedly     		1.6050	ca
# 	-2.0275	claimed        		1.5271	parker
# 	-2.0047	democratic     		1.4979	riots
# 	-1.9858	reportedly     		1.4923	cancel
# 	-1.8823	image          		1.4332	laar
# 	-1.8070	yougov         		1.4120	democrats
# 	-1.7969	widely         		1.3843	leftist
# 	-1.7779	disease        		1.3761	rioters
# 	-1.7635	care           		1.3364	friends
# 	-1.7400	amid           		1.3256	pieces
# 	-1.6963	shared         		1.3247	axios
# 	-1.6578	herald         		1.3230	tries
# 	-1.6555	critics        		1.3134	tells
# 	-1.6497	cookies        		1.2806	hoax
# 	-1.6380	baltimore      		1.2758	aoc
# 	-1.6075	editorial      		1.2700	maintained
# 	-1.5837	igor           		1.2608	today
# 	-1.5173	calif          		1.2601	media
# 	-1.5138	previous       		1.2492	ag
# 	-1.5128	clip           		1.2137	partisan
# 	-1.4980	victory        		1.2026	thought
# 	-1.4914	kushner        		1.1989	impact
# 	-1.4857	suggested      		1.1964	looking
# 	-1.4740	reporter       		1.1956	sets
# 	-1.4585	week           		1.1829	morse
# 	-1.4180	meant          		1.1826	mike
# 	-1.4071	later          		1.1809	fact
# 	-1.3895	spread         		1.1756	related
# 	-1.3760	fans           		1.1664	important
#
# hs_and_nr_bigram_sr_nol_pr
# LinearSVC Accuracy Score:  0.89937106918239
# 		Left           			Right
# 	-4.2991	article originally		2.8447	reports
# 	-4.0745	originally appeared		2.5986	dems
# 	-3.3819	originally     		2.4373	ap photo
# 	-3.3212	appeared       		2.3975	democrat
# 	-2.6780	check          		2.2633	hill
# 	-2.4861	month          		2.2312	healthcare
# 	-2.3861	democratic     		2.2129	alex
# 	-2.3665	writer         		1.9808	wuhan
# 	-2.3571	repeatedly     		1.9798	ny
# 	-2.2433	article        		1.9526	told fox
# 	-2.1103	host           		1.8350	dem
# 	-2.0392	image          		1.6246	aoc
# 	-1.9986	yougov         		1.6003	laar
# 	-1.9574	washington ap  		1.5654	maintained
# 	-1.9261	sponsored      		1.5398	rioters
# 	-1.9085	warned         		1.5154	related
# 	-1.8672	argued         		1.5084	democrats
# 	-1.8335	claimed        		1.4978	leftist
# 	-1.7482	reportedly     		1.4865	cancel
# 	-1.6847	widely         		1.4073	illegal
# 	-1.6832	critics        		1.3940	ca
# 	-1.6499	ap             		1.3925	mike bloomberg
# 	-1.6458	disease        		1.3782	mob
# 	-1.6377	twitter users  		1.3549	media
# 	-1.6295	clip           		1.3509	riots
# 	-1.5941	covid          		1.3485	woke
# 	-1.5894	footage        		1.3306	important
# 	-1.5804	staff writer   		1.3253	looking
# 	-1.5718	asked          		1.2728	tries
# 	-1.5326	guide          		1.2630	says
# 	-1.4980	digby          		1.2612	news fox
# 	-1.4881	reporter       		1.2594	axios
# 	-1.4789	meant          		1.2549	john
# 	-1.4731	care           		1.2252	ag
# 	-1.4549	right wing     		1.2173	socialist
# 	-1.4515	complained     		1.2100	best
# 	-1.4294	news host      		1.2031	continue
# 	-1.4256	public         		1.1872	opinion
# 	-1.3888	alternet       		1.1827	today
# 	-1.3791	appeared alternet		1.1758	pieces
#
# hs_and_nr_trigram_sr_nol_pr
# LinearSVC Accuracy Score:  0.8842767295597485
# 		Left           			Right
# 	-3.6201	article originally		2.9638	dems
# 	-3.4843	originally appeared		2.8605	democrat
# 	-3.3947	article originally appeared		2.7634	reports
# 	-3.0708	appeared       		2.4709	hill
# 	-3.0698	originally     		2.3713	ap photo
# 	-2.7707	check          		2.1046	healthcare
# 	-2.4226	repeatedly     		1.8724	ny
# 	-2.2937	month          		1.7995	wuhan
# 	-2.2785	writer         		1.7286	rioters
# 	-2.2267	host           		1.6897	alex
# 	-2.0383	reportedly     		1.5676	ca
# 	-2.0224	yougov         		1.4905	democrats
# 	-1.9390	argued         		1.4678	woke
# 	-1.8820	warned         		1.4659	non
# 	-1.8726	disease        		1.4634	told fox
# 	-1.7819	article        		1.4388	related
# 	-1.7501	democratic     		1.4311	tries
# 	-1.7348	footage        		1.4242	axios
# 	-1.7126	editorial      		1.4167	leftist
# 	-1.6997	users          		1.4043	schumer
# 	-1.6361	baltimore      		1.4037	tells
# 	-1.6137	week           		1.3717	cancel
# 	-1.5961	covid disease  		1.3564	john
# 	-1.5822	right wing     		1.3410	aoc
# 	-1.5450	clip           		1.3148	needs
# 	-1.5395	image          		1.3030	morning
# 	-1.5388	critics        		1.2887	cnbc
# 	-1.5197	called         		1.2734	luxury
# 	-1.4932	sponsored      		1.2613	charles
# 	-1.4858	told           		1.2604	yesterday
# 	-1.4733	covid          		1.2603	riots
# 	-1.4717	meant          		1.2412	abc news
# 	-1.4672	twitter        		1.2401	thought
# 	-1.4642	care           		1.2326	mike bloomberg
# 	-1.4630	battle         		1.2321	dc
# 	-1.4409	photo op       		1.2172	posts
# 	-1.4393	guide          		1.2137	place
# 	-1.4384	shared         		1.2048	looking
# 	-1.4354	reporter       		1.1918	leftists
# 	-1.4332	washington     		1.1590	racial
# hsr_and_nrw_onegram_sr_nol_nopr
# LinearSVC Accuracy Score:  0.8423728813559322
# 		Left           			Right
# 	-4.2243	appeared       		2.1955	hill
# 	-3.5206	originally     		2.1746	alex
# 	-2.8412	host           		2.0333	democrat
# 	-2.5138	article        		1.8866	media
# 	-2.5075	writer         		1.8387	left
# 	-2.2806	covid          		1.7973	healthcare
# 	-1.9575	explained      		1.6604	wuhan
# 	-1.9400	month          		1.6482	related
# 	-1.8876	ky             		1.6260	aoc
# 	-1.7963	users          		1.4585	dems
# 	-1.7516	repeatedly     		1.4016	laar
# 	-1.6832	calif          		1.3910	data
# 	-1.6303	suggested      		1.3801	place
# 	-1.6280	kind           		1.3679	inquiry
# 	-1.6147	check          		1.3404	rioters
# 	-1.6141	progressive    		1.2738	riots
# 	-1.5935	care           		1.2611	leftist
# 	-1.5907	read           		1.2439	borders
# 	-1.5761	failure        		1.2403	trillion
# 	-1.5327	long           		1.2222	statesof
# 	-1.5234	lgbtq          		1.1869	push
# 	-1.4996	falsely        		1.1640	biden
# 	-1.4873	twitter        		1.1588	subcommittee
# 	-1.4855	alternet       		1.1424	virus
# 	-1.4725	post           		1.1330	parker
# 	-1.4537	warned         		1.1201	pieces
# 	-1.4494	argument       		1.1198	freedom
# 	-1.4177	editorial      		1.0779	liberal
# 	-1.4120	sponsored      		1.0606	nov
# 	-1.3891	killing        		1.0589	trying
# 	-1.3790	wing           		1.0506	piece
# 	-1.3589	new            		1.0341	council
# 	-1.3486	sherman        		1.0337	custody
# 	-1.3423	image          		1.0218	outlet
# 	-1.3340	yougov         		1.0166	foods
# 	-1.3330	toll           		1.0123	socialist
# 	-1.3273	rights         		1.0107	woke
# 	-1.3191	central        		1.0074	revenue
# 	-1.3183	continued      		0.9981	decide
# 	-1.3124	sexual         		0.9908	sentiment
#
# hsr_and_nrw_bigram_sr_nol_nopr
# LinearSVC Accuracy Score:  0.8449152542372881
# 		Left           			Right
# 	-3.1470	appeared       		2.0028	democrat
# 	-2.9396	article originally		1.8140	aoc
# 	-2.7912	originally appeared		1.6956	media
# 	-2.5777	host           		1.6883	related
# 	-2.4186	originally     		1.6833	healthcare
# 	-2.2287	twitter users  		1.6698	dems
# 	-2.2126	writer         		1.6201	alex
# 	-2.1421	article        		1.5775	wuhan
# 	-2.1389	covid          		1.5591	riots
# 	-2.0299	president joe  		1.3853	left
# 	-2.0020	repeatedly     		1.3619	told fox
# 	-1.9662	right wing     		1.3483	ap photo
# 	-1.8428	ky             		1.3236	piece
# 	-1.8270	month          		1.2955	inquiry
# 	-1.7700	suggested      		1.2497	posts
# 	-1.7397	health care    		1.2478	virus
# 	-1.6910	explained      		1.2223	rioters
# 	-1.6460	reporter       		1.1926	republican said
# 	-1.6323	progressive    		1.1872	leftist
# 	-1.6184	new            		1.1676	push
# 	-1.5672	lgbtq          		1.1641	socialist
# 	-1.5094	warned         		1.1605	executive order
# 	-1.4967	mcconnell ky   		1.1505	borders
# 	-1.4876	check          		1.1415	data
# 	-1.4835	falsely        		1.1378	biden
# 	-1.4687	kind           		1.1160	rioting
# 	-1.4341	staff writer   		1.0801	woke
# 	-1.4264	yougov         		1.0773	news fox
# 	-1.4182	rights         		1.0767	decide
# 	-1.3921	clip           		1.0765	wuhan virus
# 	-1.3634	according report		1.0664	leftists
# 	-1.3631	asked          		1.0658	bipartisan
# 	-1.3613	sunday         		1.0645	nancy
# 	-1.3572	cunited        		1.0542	wants
# 	-1.3508	disease        		1.0463	place
# 	-1.3487	spokesperson   		1.0291	narrative
# 	-1.3478	noting         		1.0137	trillion
# 	-1.3272	rhetoric       		1.0108	trying
# 	-1.3253	anti           		1.0096	democrats
# 	-1.3112	video          		0.9983	police custody
#
# hsr_and_nrw_trigram_sr_nol_nopr
# LinearSVC Accuracy Score:  0.8525423728813559
# 		Left           			Right
# 	-3.1213	appeared       		2.2157	democrat
# 	-2.8573	article originally		2.0438	left
# 	-2.6401	twitter users  		1.8230	dems
# 	-2.5510	originally appeared		1.5787	healthcare
# 	-2.5023	article originally appeared		1.5233	wuhan
# 	-2.4422	host           		1.4227	ap photo
# 	-2.1804	month          		1.4021	alex
# 	-2.1444	writer         		1.3906	data
# 	-2.0148	originally     		1.3670	related
# 	-2.0000	right wing     		1.3448	dakota
# 	-1.7698	check          		1.3363	biden
# 	-1.7487	article        		1.3128	executive order
# 	-1.7326	explained      		1.2820	push
# 	-1.7104	suggested      		1.2739	posts
# 	-1.7035	repeatedly     		1.2507	trillion
# 	-1.6987	published      		1.2262	opinion
# 	-1.6954	reporter       		1.2109	told fox
# 	-1.6699	offered        		1.2025	riots
# 	-1.6636	covid          		1.1950	establishment
# 	-1.6545	progressive    		1.1632	wuhan virus
# 	-1.6325	ky             		1.1606	rioting
# 	-1.5731	failure        		1.1572	leftist
# 	-1.5621	warned         		1.1424	tweet
# 	-1.5517	bankruptcy     		1.1326	media
# 	-1.5426	anti           		1.1158	place
# 	-1.5165	lgbtq          		1.0775	youwill
# 	-1.4994	yougov         		1.0741	woke
# 	-1.4939	health care    		1.0698	consideration
# 	-1.4792	reported       		1.0664	cancel
# 	-1.4687	cunited        		1.0636	police custody
# 	-1.4676	calif          		1.0604	rioters
# 	-1.4648	care           		1.0577	republican said
# 	-1.4401	falsely        		1.0501	hill
# 	-1.4257	notes          		1.0426	effort
# 	-1.4144	presidency     		1.0334	authorization
# 	-1.4087	chair          		1.0259	spike
# 	-1.4060	crisis         		1.0254	running
# 	-1.3825	asked          		1.0020	flynn case
# 	-1.3517	sunday         		1.0001	hispanic
# 	-1.3395	long           		0.9892	told fox news
#
# hsr_and_nrw_onegram_sr_nol_pr
# LinearSVC Accuracy Score:  0.8559322033898306
# 		Left           			Right
# 	-4.1063	appeared       		2.5603	democrat
# 	-3.4943	originally     		2.1629	hill
# 	-2.7078	host           		1.9833	alex
# 	-2.6682	article        		1.9510	dems
# 	-2.1572	writer         		1.9108	left
# 	-2.0985	ky             		1.8256	media
# 	-2.0039	covid          		1.7328	wuhan
# 	-1.9331	warned         		1.6556	healthcare
# 	-1.9047	month          		1.6538	riots
# 	-1.8754	explained      		1.6361	aoc
# 	-1.8246	repeatedly     		1.4971	trillion
# 	-1.7798	calif          		1.4392	rioters
# 	-1.7190	suggested      		1.4163	data
# 	-1.7131	continued      		1.3852	push
# 	-1.6800	users          		1.3056	biden
# 	-1.6026	reporter       		1.2894	virus
# 	-1.5885	states         		1.2511	posts
# 	-1.5500	twitter        		1.2166	gray
# 	-1.5475	reported       		1.2111	leftist
# 	-1.5419	refused        		1.2069	enforcement
# 	-1.5233	progressive    		1.2028	caller
# 	-1.5170	published      		1.1960	consideration
# 	-1.5111	anti           		1.1741	narrative
# 	-1.5098	americans      		1.1574	related
# 	-1.5074	alternet       		1.1568	need
# 	-1.4976	updates        		1.1409	laar
# 	-1.4869	presidency     		1.1373	presumptive
# 	-1.4822	care           		1.1144	communist
# 	-1.4660	killing        		1.1083	inquiry
# 	-1.4656	rhetoric       		1.1040	funding
# 	-1.4601	image          		1.0795	parker
# 	-1.4505	clip           		1.0718	woke
# 	-1.4467	wing           		1.0646	ferrer
# 	-1.4329	post           		1.0386	asymptomatic
# 	-1.4211	sexual         		1.0385	freedom
# 	-1.4173	read           		1.0375	statesof
# 	-1.4068	yougov         		1.0371	outlet
# 	-1.4019	interview      		1.0363	pieces
# 	-1.3943	beast          		1.0360	television
# 	-1.3573	check          		1.0316	agenda
# hsr_and_nrw_bigram_sr_nol_pr
# LinearSVC Accuracy Score:  0.8652542372881356
# 		Left           			Right
# 	-3.5796	appeared       		2.7112	democrat
# 	-3.1130	article originally		1.8567	aoc
# 	-2.8196	originally appeared		1.6417	told fox
# 	-2.5411	host           		1.5318	wuhan
# 	-2.4587	originally     		1.5174	media
# 	-2.4216	twitter users  		1.5096	dems
# 	-2.1707	writer         		1.4772	healthcare
# 	-2.0739	covid          		1.4761	rioters
# 	-1.9809	article        		1.4436	ap photo
# 	-1.9633	right wing     		1.4090	riots
# 	-1.8604	repeatedly     		1.3917	left
# 	-1.8229	president joe  		1.3804	data
# 	-1.7917	month          		1.3789	posts
# 	-1.7840	check          		1.3417	leftist
# 	-1.7609	progressive    		1.3334	hill
# 	-1.7568	image          		1.3268	alex
# 	-1.7256	ky             		1.3151	told politico
# 	-1.5819	treatment      		1.3089	republican said
# 	-1.5812	offered        		1.2856	trillion
# 	-1.5645	health care    		1.2721	place
# 	-1.5398	states         		1.2637	push
# 	-1.5222	long           		1.2437	related
# 	-1.5030	bankruptcy     		1.2282	wuhan virus
# 	-1.4999	column         		1.2172	executive order
# 	-1.4683	interview      		1.2086	biden
# 	-1.4612	sunday         		1.1472	rioting
# 	-1.4514	read           		1.1187	freedom
# 	-1.4357	kind           		1.1161	subcommittee
# 	-1.4289	explained      		1.0932	official told
# 	-1.4200	yougov         		1.0616	dakota
# 	-1.4076	lgbtq          		1.0473	communist
# 	-1.3959	mcconnell ky   		1.0455	virus
# 	-1.3955	presidency     		1.0320	zone
# 	-1.3840	failure        		1.0146	accuses
# 	-1.3822	experts        		1.0143	message
# 	-1.3748	reporter       		1.0078	twitter facebook
# 	-1.3534	anti           		1.0035	said white
# 	-1.3427	said statement 		1.0022	north
# 	-1.3362	ukraine        		0.9895	socialist
# 	-1.3293	suggested      		0.9860	decide
#
# hsr_and_nrw_trigram_sr_nol_pr
# LinearSVC Accuracy Score:  0.8533898305084746
# 		Left           			Right
# 	-3.0247	appeared       		1.9430	democrat
# 	-2.8543	article originally		1.7848	left
# 	-2.6399	host           		1.7690	wuhan
# 	-2.4829	article originally appeared		1.7663	media
# 	-2.4236	originally appeared		1.4959	healthcare
# 	-2.2984	twitter users  		1.4750	dems
# 	-2.2026	warned         		1.4539	told fox
# 	-2.1905	originally     		1.4391	ap photo
# 	-2.0038	repeatedly     		1.3847	related
# 	-1.9916	right wing     		1.3540	alex
# 	-1.9686	explained      		1.3400	riots
# 	-1.9417	covid          		1.3339	wuhan virus
# 	-1.8971	article        		1.3237	trillion
# 	-1.8830	writer         		1.3060	push
# 	-1.8741	check          		1.3049	leftist
# 	-1.6664	ky             		1.3016	narrative
# 	-1.6534	health care    		1.2979	place
# 	-1.6391	interview      		1.2892	hill
# 	-1.5960	progressive    		1.2564	told fox news
# 	-1.5730	sunday         		1.2134	message
# 	-1.5278	lgbtq          		1.2103	republican said
# 	-1.5019	attorney       		1.2080	consideration
# 	-1.4611	claimed        		1.2067	communist
# 	-1.4590	conspiracy     		1.2041	inquiry
# 	-1.3999	notes          		1.1951	biden
# 	-1.3964	anti           		1.1756	zone
# 	-1.3930	image          		1.1657	woke
# 	-1.3874	published      		1.1362	borders
# 	-1.3672	post           		1.1314	rioters
# 	-1.3602	yougov         		1.1284	freedom
# 	-1.3332	long           		1.1105	legislature
# 	-1.3265	offered        		1.1072	youwill
# 	-1.3176	conference     		1.0994	outlet
# 	-1.3086	suggested      		1.0535	democrats
# 	-1.3086	users          		1.0460	plus
# 	-1.2916	harvey         		1.0453	trying
# 	-1.2907	new            		1.0406	subcommittee
# 	-1.2907	monday         		1.0370	establishment
# 	-1.2903	failure        		1.0366	ultimate
# 	-1.2856	continued      		1.0294	rioting

# %% [markdown]
# ### Look at all possible unique features

# %%
# Using keep='false' in drop_duplicates is not appropriate here...
unique = np.array(top_features_arr)
unique_rows = np.unique(unique, axis=1)
final_features_df = pd.DataFrame(unique,
                   columns=['value', 'feature'])
final_features_df.head()
# Out:
#                 value  feature
# 0  3.9325003555540214  reports
# 1   3.823050335460375  reports
# 2  3.8161506727343366  reports
# 3  3.8107319715082952  reports
# 4   3.641659823684234  reports

# %%
# keep = False: if there's 2 occurences of a word it drops both entries.....it doesn't keep one.

# keep = first, drops all duplicates except for first occurence
# keep = False, drops all duplicates...does not keep even one for unique purposes
# keep = last, drops all duplicates except for the last occurence
final_features_df.drop_duplicates('feature', keep=False, inplace=True)
final_features_df.head()
# Out:
#                   value         feature
# 214  1.5317889809668035          posted
# 289  1.4290840821701043  democratic gov
# 292  1.4256839011809639       said said
# 304  1.4124845798896726            want
# 317  1.3973836859458693      activities

# %%
final_features_df[final_features_df['feature'].str.contains("reports")]
# Out:
# Empty DataFrame
# Columns: [value, feature]
# Index: []

# %%
final_features_df[final_features_df['feature'].str.contains("healthcare")]
# Out:
# Empty DataFrame
# Columns: [value, feature]
# Index: []

# %%
# Using keep = 'first' or keep='last' is appropriate...
unique = np.array(top_features_arr)
unique_rows = np.unique(unique, axis=1)
final_features_df = pd.DataFrame(unique,
                   columns=['value', 'feature'])
final_features_df.head()
# Out:
#                 value  feature
# 0  3.9325003555540214  reports
# 1   3.823050335460375  reports
# 2  3.8161506727343366  reports
# 3  3.8107319715082952  reports
# 4   3.641659823684234  reports

# %%
# keep = 'first': Seems to be what I need.

# keep = first, drops all duplicates except for first occurence
# keep = False, drops all duplicates...does not keep even one for unique purposes
# keep = last, drops all duplicates except for the last occurence
final_features_df.drop_duplicates('feature', keep='first', inplace=True)
final_features_df.head()
# Out:
#                  value     feature
# 0   3.9325003555540214     reports
# 6   3.2264103845891325        hill
# 7    3.224506154884109  healthcare
# 15  2.9691161560846884        dems
# 17   2.917305230892811        alex

# %%
final_features_df[final_features_df['feature'].str.contains("reports")]
# Out:
#                   value       feature
# 0    3.9325003555540214       reports
# 122  1.8330685405653704  news reports

# %%
final_features_df[final_features_df['feature'].str.contains("healthcare")]
# Out:
#                value     feature
# 7  3.224506154884109  healthcare

# %%
# Store the top features
left_features = []
right_features = []

for x in range(len(top_features_arr)):
    if top_features_arr[x][0] > 0:
        right_features.append([top_features_arr[x][0], top_features_arr[x][1]])
    else:
        left_features.append([top_features_arr[x][0], top_features_arr[x][1]])

# %%
# Left features
left_arr = np.array(left_features)
left = pd.DataFrame(left_arr, columns=['value', 'feature'])
left.drop_duplicates('feature', keep='last', inplace=True)
left.head()
# Out:
#                   value     feature
# 2    -1.290704361244009      monday
# 4   -1.2916306738210865      harvey
# 9   -1.3175563616922499  conference
# 11  -1.3190698040053763     central
# 17   -1.332989252352926        toll

# %%
# Right features
right_arr = np.array(right_features)
right = pd.DataFrame(right_arr, columns=['value', 'feature'])
right.drop_duplicates('feature', keep='first', inplace=True)
right.head()
# Out:
#                  value     feature
# 0   3.9325003555540214     reports
# 6   3.2264103845891325        hill
# 7    3.224506154884109  healthcare
# 15  2.9691161560846884        dems
# 17   2.917305230892811        alex

# %%
# All features
all_data = pd.concat([right, left])
all_data.head()
# Out:
#                  value     feature
# 0   3.9325003555540214     reports
# 6   3.2264103845891325        hill
# 7    3.224506154884109  healthcare
# 15  2.9691161560846884        dems
# 17   2.917305230892811        alex

# %%
# Some are seen twice on left and right here...
# Now keep=False is appropriate...as that is noise.

#for x in range(all_data.shape[0]):
#    print([all_data.value[x], all_data.feature[x]])
print(all_data.to_string())
# Out:
#                    value                      feature
# 0     3.9325003555540214                      reports
# 6     3.2264103845891325                         hill
# 7      3.224506154884109                   healthcare
# 15    2.9691161560846884                         dems
# 17     2.917305230892811                         alex
# 18    2.8604847412960104                     democrat
# 51    2.4622448392266563                     ap photo
# 57    2.3439219909390343                    according
# 58    2.3424998325442505                           ny
# 61    2.3039161767928875                        wuhan
# 69     2.227813824108311                hill reported
# 89    2.0437999069881134                         left
# 91     2.021687651886388                         mike
# 92     2.004913431265343                     politico
# 98    1.9525983346840972                     told fox
# 104   1.9073663927749793                          dem
# 106   1.8994594308070847                         fall
# 107   1.8865516633062396                        media
# 108   1.8829578741092108                        riots
# 112    1.869944124341331                      rioters
# 113   1.8658589860300863                    democrats
# 115   1.8566925326822623                          aoc
# 122   1.8330685405653704                 news reports
# 138   1.7665033121178806                           wh
# 142   1.7436076201347337                  news outlet
# 146   1.7311688166644619                    communist
# 152    1.688306287772049                      related
# 158   1.6696189018126046           global coronavirus
# 159   1.6664935217376649               police custody
# 168   1.6489430642019545                        gizzi
# 171   1.6369075504696458                         woke
# 174   1.6339566744523015                     chairman
# 175   1.6319390930563762               mike bloomberg
# 176   1.6299830363121162               according hill
# 184   1.6050025335894744                           ca
# 185   1.6010960597157737                      morning
# 186   1.6003100482266095                         laar
# 188   1.5956791181151566                        tries
# 190   1.5834857708734102                      tweeted
# 200   1.5653813034471953                   maintained
# 202    1.561122949549732                        think
# 204   1.5511658168881692                     civilian
# 206   1.5497135685817482                        today
# 209   1.5461679686957386                       pieces
# 210   1.5455494060062884                        axios
# 214   1.5317889809668035                       posted
# 216    1.528152389863689                        virus
# 217   1.5271313247515024                       parker
# 220   1.5229417381801333         republican president
# 224   1.5119253053471988                           ch
# 228    1.505924952446457                      leftist
# 230   1.5037310984547099                          cbs
# 235   1.4990031095131264                          gen
# 239   1.4971137484548533                     trillion
# 243   1.4951698026029514                  said friday
# 244   1.4933214849082783                   discunited
# 245    1.492320037255379                       cancel
# 247   1.4904179921048828                        posts
# 252   1.4812098510838996                      schumer
# 261   1.4733106436208325                      liberal
# 262    1.468704620347078                    criticism
# 264   1.4658880085198531                          non
# 269    1.457781727753499                      illegal
# 272   1.4536689255494062                      intends
# 273   1.4520091404208764                     news fox
# 277   1.4410825718350815                comments came
# 283   1.4346033163146041                           dc
# 284   1.4336771332831286                        iwill
# 287   1.4311579973299398                         john
# 289   1.4290840821701043               democratic gov
# 292   1.4256839011809639                    said said
# 297   1.4191319408668086                       luxury
# 300   1.4163481618701537                          mob
# 301   1.4163034195158308                         data
# 302   1.4140109463803492                     cbs news
# 304   1.4124845798896726                         want
# 312    1.403666929381627                        tells
# 317   1.3973836859458693                   activities
# 318   1.3971851923828655                        total
# 331    1.389686315349757                       strong
# 332   1.3887931042682178                        place
# 333   1.3886456974973922  global coronavirus pandemic
# 334   1.3871215568507957             news fox friends
# 336    1.385174373020911                         push
# 346   1.3796007733945315                  fox friends
# 349    1.378448658094192                        order
# 352   1.3759683594632237                         july
# 356   1.3698422035893885                    integrity
# 358   1.3678953573989385                      inquiry
# 374   1.3500645595094947                    yesterday
# 376   1.3488439616999497                        probe
# 379    1.347974443965561                         tech
# 380   1.3447588839957858                       dakota
# 388   1.3364135094580867                      friends
# 389   1.3363443651324964                        biden
# 391   1.3348098350235607                      african
# 393   1.3338609125787266                  wuhan virus
# 395   1.3316776910566195                      refusal
# 396   1.3316310039334143                        built
# 397    1.330646874358263                    important
# 399   1.3295338001082404                     newsroom
# 401   1.3293314073283933                          joe
# 402   1.3292950888019903                    commented
# 403   1.3291339842396632                      journal
# 404   1.3283695023168238                opinion piece
# 409   1.3253429526580915                      looking
# 410   1.3250993254406578              rights reserved
# 414     1.32360387329524                        piece
# 417   1.3209053670089894                       blasts
# 419   1.3203299255616348                          nov
# 420   1.3201807422024825                    socialist
# 421   1.3185136579469259                         cnbc
# 424   1.3177667097305124                      provide
# 426   1.3151268228639736                told politico
# 427   1.3148247782844145                        needs
# 429   1.3127849582095443              executive order
# 431   1.3089418808739866              republican said
# 442   1.3015781696388198                    narrative
# 455   1.2880103523068072                         nazi
# 456   1.2865941960347649                      percent
# 457    1.286423127022113                       native
# 459   1.2846093852337135                    rejecting
# 460   1.2837401253258527                       sought
# 464   1.2805552824527042                         hoax
# 467   1.2763537650687882                       bernie
# 473   1.2738949456255892                         meet
# 481    1.270562822524371                       attend
# 483    1.269833466728121         obama administration
# 485   1.2650796211044066                      thought
# 487    1.262966640061283                         says
# 488   1.2613238856316895                      charles
# 498   1.2563625921986552                told fox news
# 500   1.2552081947891176                    criminals
# 501   1.2551956744201087               senior adviser
# 504   1.2535260418731256                          nbc
# 509   1.2498439282824465                      favored
# 511   1.2491612262868665                           ag
# 512   1.2487221502472468                      seattle
# 515    1.245933772458288                    hollywood
# 516   1.2438535345122181                      borders
# 520   1.2412114357557171                     abc news
# 527   1.2348793652711967                        tweet
# 528   1.2337318551496064                      holding
# 532   1.2298407103934166                       mexico
# 534   1.2295092515513457                           vp
# 535   1.2294984145012207                        crazy
# 538   1.2262339172636503                      opinion
# 541   1.2237893715192065                      hillary
# 542   1.2233722405275287                    acquitted
# 544   1.2221708452506546                     statesof
# 550   1.2168875129867351                      brought
# 551   1.2166372736235624                         gray
# 553   1.2152151017440613                       ferrer
# 558   1.2136853796011542                     partisan
# 560   1.2134352528531183                      message
# 566    1.210044129142448                         best
# 568    1.208024542064712                consideration
# 569   1.2069040598843521                  enforcement
# 573   1.2030895947091198                     continue
# 574   1.2028075230075017                       caller
# 579   1.2001110355333262                      express
# 581   1.1995071603454728                         hall
# 583   1.1988520571017303                       impact
# 586   1.1957766226564925                     stressed
# 588   1.1955894502788356                         sets
# 590   1.1949969666582185                establishment
# 594   1.1918343050565856                     leftists
# 599    1.183194518023666                           st
# 600   1.1829142732162194                        morse
# 603   1.1809112872056664                         fact
# 605   1.1756235130984307                         zone
# 617   1.1606345852095554                      rioting
# 619   1.1590304221489625                       racial
# 620   1.1588368958116144                 subcommittee
# 623     1.15679003989422                         need
# 631   1.1372907698034953                  presumptive
# 636    1.128375317781899                      freedom
# 644   1.1104638804326008                  legislature
# 646   1.1071868194735524                      youwill
# 647    1.104032159120079                      funding
# 648   1.0994311335171447                       outlet
# 649   1.0931998763288417                official told
# 655    1.076712072369074                       decide
# 662   1.0658012782717337                   bipartisan
# 664   1.0645327084368785                        nancy
# 669   1.0588804376763528                       trying
# 671   1.0542464511630205                        wants
# 677   1.0459631715545215                         plus
# 680    1.042561794500531                       effort
# 682   1.0385669189503617                 asymptomatic
# 687    1.036633549134197                     ultimate
# 689   1.0359639390103992                   television
# 690   1.0341349583456334                      council
# 691   1.0336698632520334                      custody
# 692   1.0334322831602631                authorization
# 694    1.031625264776258                       agenda
# 697   1.0259201151095279                        spike
# 698    1.025367346544479                      running
# 700   1.0166427542506107                        foods
# 701   1.0146353280775382                      accuses
# 708   1.0077856919439256             twitter facebook
# 709   1.0074180984478922                      revenue
# 710   1.0034723827068013                   said white
# 711    1.002212496612442                        north
# 712    1.002009275206553                   flynn case
# 713    1.000109659095118                     hispanic
# 716   0.9908347182515854                    sentiment
# 2     -1.290704361244009                       monday
# 4    -1.2916306738210865                       harvey
# 9    -1.3175563616922499                   conference
# 11   -1.3190698040053763                      central
# 17    -1.332989252352926                         toll
# 20     -1.33618204223107                      ukraine
# 23   -1.3427305583688238               said statement
# 25   -1.3486273857359818                      sherman
# 38   -1.3634088352812905             according report
# 42   -1.3766046844300557                    wednesday
# 46    -1.382239843462282                      experts
# 55   -1.3942778056246317                        beast
# 61    -1.402952303851155         coronavirus pandemic
# 62   -1.4059728636238218                       crisis
# 66   -1.4086783694569307                        chair
# 78    -1.418210751018704                       rights
# 80    -1.421097010770925                       sexual
# 82   -1.4256803788077843                        notes
# 85   -1.4291351703382231                work appeared
# 89   -1.4311571021224205                         fans
# 91    -1.433171242016044                   washington
# 103   -1.446699493488136                         wing
# 104  -1.4493837093278443                     argument
# 109  -1.4543815706814895                       spread
# 112  -1.4589513284764886                   conspiracy
# 119  -1.4655523909262176                     rhetoric
# 120  -1.4659962148295758                      killing
# 124  -1.4686586040791967                      cunited
# 126     -1.4701063931482                    news host
# 128  -1.4725331371845514                       public
# 129  -1.4725438300695306                         post
# 131  -1.4732122615995338                    described
# 142  -1.4858063942975523                         told
# 143  -1.4869436564939291                   presidency
# 147   -1.491370352889867                      kushner
# 150  -1.4966803774292445                 mcconnell ky
# 151  -1.4975955122158697                      updates
# 152  -1.4980005422130114                      victory
# 153   -1.498030303606754                        digby
# 155  -1.4991392708439624                     photo op
# 157   -1.499574495891183                      falsely
# 158  -1.4998892668213035                       column
# 159   -1.501942732861652                     attorney
# 160   -1.502822941297362                   complained
# 165  -1.5098443861274928                    americans
# 168  -1.5137963899024556                     previous
# 172  -1.5196980912771265                       called
# 182  -1.5326650728507867                         long
# 189  -1.5419084448744274                      refused
# 193  -1.5474641135863174                     reported
# 195  -1.5517126179978393                   bankruptcy
# 196   -1.557582243141587                     demanded
# 197   -1.559458488707399                       battle
# 201  -1.5671951167639238                        lgbtq
# 203  -1.5729810193910996                       sunday
# 205  -1.5742388245059018                       middle
# 206  -1.5760885305959471                      failure
# 209  -1.5803924098861852                 staff writer
# 213  -1.5818712276257536                    treatment
# 216  -1.5853309583535713        contributed reporting
# 217  -1.5884879931644287                       states
# 229  -1.6047304877761817                   downplayed
# 230  -1.6050145286095947                  anti racism
# 234   -1.609225006882768            appeared alternet
# 235  -1.6095714644436687                       noting
# 239  -1.6121316175713225                    currently
# 244  -1.6154108606912436                        basic
# 245  -1.6184468274681332                          new
# 249  -1.6256648117269785                        means
# 250  -1.6270392102671198                       showed
# 251  -1.6279739793875343                         kind
# 254  -1.6312893954095633                        claim
# 261  -1.6391033065375415                    interview
# 270  -1.6497045116492235                      cookies
# 278  -1.6561839749296547                      scandal
# 280  -1.6612197514389344                       herald
# 284   -1.664405441010449                         vice
# 293  -1.6770104116070859                         igor
# 294   -1.678321335765951                      earlier
# 296  -1.6800970391117533                    initially
# 302    -1.68540435467463                covid disease
# 305  -1.6898830917195446                         year
# 310  -1.6947780123185148                       latest
# 312  -1.6962661830333399                       shared
# 313  -1.6987457212243176                    published
# 321  -1.7120317607217834               disease caused
# 324  -1.7131245683907632                    continued
# 326  -1.7165025749901077                     believed
# 329  -1.7245370456387945                  contributed
# 332  -1.7253249709726945                   population
# 334  -1.7284421366660883                      despite
# 335  -1.7290050070926262                     attacked
# 341  -1.7396600450986737                  health care
# 345  -1.7481236864861989                    statement
# 351   -1.755614212191207                      twitter
# 353   -1.759562240231179                         clip
# 366  -1.7797295285294101                      updated
# 372  -1.7862849881304486                         week
# 374  -1.7876969175112898                   check clip
# 384  -1.7968694691535856                       widely
# 391  -1.8100371474885046                        video
# 392    -1.81649759824445                         read
# 394  -1.8187053111855311                      analyst
# 399  -1.8253582378924342                assassination
# 401  -1.8273347191703841                      footage
# 403  -1.8287784012798765                      sunited
# 405  -1.8314296060490178                         anti
# 406  -1.8320041045749997                         care
# 407  -1.8325858262506998                   reelection
# 409   -1.838583160917515                        urged
# 410  -1.8400594958430279                        meant
# 413  -1.8440530416764174                        major
# 418   -1.856732197860341                          old
# 425  -1.8666498823744737                      offered
# 426  -1.8670300927368713                 spokesperson
# 430  -1.8750730099980852                       racist
# 438   -1.887768681592472                     announce
# 443  -1.8975287915291812                    confirmed
# 451   -1.927297978099448                    reporting
# 455   -1.934237239692857                    baltimore
# 461  -1.9433473015196419                      editing
# 462  -1.9465076917333077            guide coronavirus
# 472  -1.9686263349128073                    explained
# 478  -1.9822172403488043                      disease
# 483  -1.9999888757083322                   right wing
# 494  -2.0268962112169935                         live
# 496  -2.0298513224868286                president joe
# 501   -2.039207221411183                        image
# 503    -2.04249117852495                        later
# 504  -2.0468285461010827                        rival
# 509   -2.073124900436218                      critics
# 512   -2.088794908500206                        guide
# 517  -2.0985498107653804                           ky
# 518   -2.104012308710625                    sponsored
# 525   -2.120413847564607                    editorial
# 536   -2.149166895012906                       argued
# 538  -2.1558825840983937                        asked
# 550   -2.205740235301349                     alternet
# 552  -2.2104913024501833                   correction
# 561  -2.2441043800853033                     zelensky
# 562  -2.2575298165334976                         amid
# 565   -2.277779394961138                        calif
# 571  -2.2965376569570197                   previously
# 574  -2.3195098828233185                     reporter
# 586    -2.38611550908163                   democratic
# 601  -2.4625346710243927                  progressive
# 617  -2.5699515192865348                       yougov
# 628  -2.6401104870424112                twitter users
# 631  -2.6684521703648394                   apparently
# 636  -2.6994918955388045                       warned
# 655   -2.863057744541917                        month
# 656  -2.8850607814421827                         host
# 657   -2.886772652902187                       writer
# 658  -2.9093963489601373                    suggested
# 659  -2.9189911070134693                      claimed
# 665  -2.9705439395846747                   repeatedly
# 668  -3.0248621629073473                        covid
# 671  -3.1094767567174983                        users
# 680   -3.192033557546624                   reportedly
# 685   -3.394711012958541  article originally appeared
# 693  -3.5590053846549807                      article
# 702   -3.870103753204572                washington ap
# 703   -3.883255816222963                        check
# 708    -4.14773567813678          originally appeared
# 713   -4.337321383170747           article originally
# 716  -4.6927488948692035                           ap
# 717  -5.1704126298023345                     appeared
# 719   -5.512033913780874                   originally

# %% [markdown]
# # Final Features

# %%
# Here, keep=False is actually useful.
# If a feature shows up in the left and right...it shouldn't be in either.
# That's due to articles being split 80/20 in a strange fashion 
# or 6 sources vs 4 or 2 could bring in more occurences of the word for that particular side.
# Ex: 'president donald' - frequency of -5.12 in left....4.82 in right.
# - This wouldn't make sense as this bigram can't appear 5 times more in left articles than right
# - and 4.8 times more in right articles than left at the same time.
all_data.drop_duplicates('feature', keep=False, inplace=True)
print(all_data.to_string())
# Out:
#                    value                      feature
# 0     3.9325003555540214                      reports
# 6     3.2264103845891325                         hill
# 7      3.224506154884109                   healthcare
# 15    2.9691161560846884                         dems
# 17     2.917305230892811                         alex
# 18    2.8604847412960104                     democrat
# 51    2.4622448392266563                     ap photo
# 57    2.3439219909390343                    according
# 58    2.3424998325442505                           ny
# 61    2.3039161767928875                        wuhan
# 69     2.227813824108311                hill reported
# 89    2.0437999069881134                         left
# 91     2.021687651886388                         mike
# 92     2.004913431265343                     politico
# 98    1.9525983346840972                     told fox
# 104   1.9073663927749793                          dem
# 106   1.8994594308070847                         fall
# 107   1.8865516633062396                        media
# 108   1.8829578741092108                        riots
# 112    1.869944124341331                      rioters
# 113   1.8658589860300863                    democrats
# 115   1.8566925326822623                          aoc
# 122   1.8330685405653704                 news reports
# 138   1.7665033121178806                           wh
# 142   1.7436076201347337                  news outlet
# 146   1.7311688166644619                    communist
# 152    1.688306287772049                      related
# 158   1.6696189018126046           global coronavirus
# 159   1.6664935217376649               police custody
# 168   1.6489430642019545                        gizzi
# 171   1.6369075504696458                         woke
# 174   1.6339566744523015                     chairman
# 175   1.6319390930563762               mike bloomberg
# 176   1.6299830363121162               according hill
# 184   1.6050025335894744                           ca
# 185   1.6010960597157737                      morning
# 186   1.6003100482266095                         laar
# 188   1.5956791181151566                        tries
# 190   1.5834857708734102                      tweeted
# 200   1.5653813034471953                   maintained
# 202    1.561122949549732                        think
# 204   1.5511658168881692                     civilian
# 206   1.5497135685817482                        today
# 209   1.5461679686957386                       pieces
# 210   1.5455494060062884                        axios
# 214   1.5317889809668035                       posted
# 216    1.528152389863689                        virus
# 217   1.5271313247515024                       parker
# 220   1.5229417381801333         republican president
# 224   1.5119253053471988                           ch
# 228    1.505924952446457                      leftist
# 230   1.5037310984547099                          cbs
# 235   1.4990031095131264                          gen
# 239   1.4971137484548533                     trillion
# 243   1.4951698026029514                  said friday
# 244   1.4933214849082783                   discunited
# 245    1.492320037255379                       cancel
# 247   1.4904179921048828                        posts
# 252   1.4812098510838996                      schumer
# 261   1.4733106436208325                      liberal
# 262    1.468704620347078                    criticism
# 264   1.4658880085198531                          non
# 269    1.457781727753499                      illegal
# 272   1.4536689255494062                      intends
# 273   1.4520091404208764                     news fox
# 277   1.4410825718350815                comments came
# 283   1.4346033163146041                           dc
# 284   1.4336771332831286                        iwill
# 287   1.4311579973299398                         john
# 289   1.4290840821701043               democratic gov
# 292   1.4256839011809639                    said said
# 297   1.4191319408668086                       luxury
# 300   1.4163481618701537                          mob
# 301   1.4163034195158308                         data
# 302   1.4140109463803492                     cbs news
# 304   1.4124845798896726                         want
# 312    1.403666929381627                        tells
# 317   1.3973836859458693                   activities
# 318   1.3971851923828655                        total
# 331    1.389686315349757                       strong
# 332   1.3887931042682178                        place
# 333   1.3886456974973922  global coronavirus pandemic
# 334   1.3871215568507957             news fox friends
# 336    1.385174373020911                         push
# 346   1.3796007733945315                  fox friends
# 349    1.378448658094192                        order
# 352   1.3759683594632237                         july
# 356   1.3698422035893885                    integrity
# 358   1.3678953573989385                      inquiry
# 374   1.3500645595094947                    yesterday
# 376   1.3488439616999497                        probe
# 379    1.347974443965561                         tech
# 380   1.3447588839957858                       dakota
# 388   1.3364135094580867                      friends
# 389   1.3363443651324964                        biden
# 391   1.3348098350235607                      african
# 393   1.3338609125787266                  wuhan virus
# 395   1.3316776910566195                      refusal
# 396   1.3316310039334143                        built
# 397    1.330646874358263                    important
# 399   1.3295338001082404                     newsroom
# 401   1.3293314073283933                          joe
# 402   1.3292950888019903                    commented
# 403   1.3291339842396632                      journal
# 404   1.3283695023168238                opinion piece
# 409   1.3253429526580915                      looking
# 410   1.3250993254406578              rights reserved
# 414     1.32360387329524                        piece
# 417   1.3209053670089894                       blasts
# 419   1.3203299255616348                          nov
# 420   1.3201807422024825                    socialist
# 421   1.3185136579469259                         cnbc
# 424   1.3177667097305124                      provide
# 426   1.3151268228639736                told politico
# 427   1.3148247782844145                        needs
# 429   1.3127849582095443              executive order
# 431   1.3089418808739866              republican said
# 442   1.3015781696388198                    narrative
# 455   1.2880103523068072                         nazi
# 456   1.2865941960347649                      percent
# 457    1.286423127022113                       native
# 459   1.2846093852337135                    rejecting
# 460   1.2837401253258527                       sought
# 464   1.2805552824527042                         hoax
# 467   1.2763537650687882                       bernie
# 473   1.2738949456255892                         meet
# 481    1.270562822524371                       attend
# 483    1.269833466728121         obama administration
# 485   1.2650796211044066                      thought
# 487    1.262966640061283                         says
# 488   1.2613238856316895                      charles
# 498   1.2563625921986552                told fox news
# 500   1.2552081947891176                    criminals
# 501   1.2551956744201087               senior adviser
# 504   1.2535260418731256                          nbc
# 509   1.2498439282824465                      favored
# 511   1.2491612262868665                           ag
# 512   1.2487221502472468                      seattle
# 515    1.245933772458288                    hollywood
# 516   1.2438535345122181                      borders
# 520   1.2412114357557171                     abc news
# 527   1.2348793652711967                        tweet
# 528   1.2337318551496064                      holding
# 532   1.2298407103934166                       mexico
# 534   1.2295092515513457                           vp
# 535   1.2294984145012207                        crazy
# 538   1.2262339172636503                      opinion
# 541   1.2237893715192065                      hillary
# 542   1.2233722405275287                    acquitted
# 544   1.2221708452506546                     statesof
# 550   1.2168875129867351                      brought
# 551   1.2166372736235624                         gray
# 553   1.2152151017440613                       ferrer
# 558   1.2136853796011542                     partisan
# 560   1.2134352528531183                      message
# 566    1.210044129142448                         best
# 568    1.208024542064712                consideration
# 569   1.2069040598843521                  enforcement
# 573   1.2030895947091198                     continue
# 574   1.2028075230075017                       caller
# 579   1.2001110355333262                      express
# 581   1.1995071603454728                         hall
# 583   1.1988520571017303                       impact
# 586   1.1957766226564925                     stressed
# 588   1.1955894502788356                         sets
# 590   1.1949969666582185                establishment
# 594   1.1918343050565856                     leftists
# 599    1.183194518023666                           st
# 600   1.1829142732162194                        morse
# 603   1.1809112872056664                         fact
# 605   1.1756235130984307                         zone
# 617   1.1606345852095554                      rioting
# 619   1.1590304221489625                       racial
# 620   1.1588368958116144                 subcommittee
# 623     1.15679003989422                         need
# 631   1.1372907698034953                  presumptive
# 636    1.128375317781899                      freedom
# 644   1.1104638804326008                  legislature
# 646   1.1071868194735524                      youwill
# 647    1.104032159120079                      funding
# 648   1.0994311335171447                       outlet
# 649   1.0931998763288417                official told
# 655    1.076712072369074                       decide
# 662   1.0658012782717337                   bipartisan
# 664   1.0645327084368785                        nancy
# 669   1.0588804376763528                       trying
# 671   1.0542464511630205                        wants
# 677   1.0459631715545215                         plus
# 680    1.042561794500531                       effort
# 682   1.0385669189503617                 asymptomatic
# 687    1.036633549134197                     ultimate
# 689   1.0359639390103992                   television
# 690   1.0341349583456334                      council
# 691   1.0336698632520334                      custody
# 692   1.0334322831602631                authorization
# 694    1.031625264776258                       agenda
# 697   1.0259201151095279                        spike
# 698    1.025367346544479                      running
# 700   1.0166427542506107                        foods
# 701   1.0146353280775382                      accuses
# 708   1.0077856919439256             twitter facebook
# 709   1.0074180984478922                      revenue
# 710   1.0034723827068013                   said white
# 711    1.002212496612442                        north
# 712    1.002009275206553                   flynn case
# 713    1.000109659095118                     hispanic
# 716   0.9908347182515854                    sentiment
# 2     -1.290704361244009                       monday
# 4    -1.2916306738210865                       harvey
# 9    -1.3175563616922499                   conference
# 11   -1.3190698040053763                      central
# 17    -1.332989252352926                         toll
# 20     -1.33618204223107                      ukraine
# 23   -1.3427305583688238               said statement
# 25   -1.3486273857359818                      sherman
# 38   -1.3634088352812905             according report
# 42   -1.3766046844300557                    wednesday
# 46    -1.382239843462282                      experts
# 55   -1.3942778056246317                        beast
# 61    -1.402952303851155         coronavirus pandemic
# 62   -1.4059728636238218                       crisis
# 66   -1.4086783694569307                        chair
# 78    -1.418210751018704                       rights
# 80    -1.421097010770925                       sexual
# 82   -1.4256803788077843                        notes
# 85   -1.4291351703382231                work appeared
# 89   -1.4311571021224205                         fans
# 91    -1.433171242016044                   washington
# 103   -1.446699493488136                         wing
# 104  -1.4493837093278443                     argument
# 109  -1.4543815706814895                       spread
# 112  -1.4589513284764886                   conspiracy
# 119  -1.4655523909262176                     rhetoric
# 120  -1.4659962148295758                      killing
# 124  -1.4686586040791967                      cunited
# 126     -1.4701063931482                    news host
# 128  -1.4725331371845514                       public
# 129  -1.4725438300695306                         post
# 131  -1.4732122615995338                    described
# 142  -1.4858063942975523                         told
# 143  -1.4869436564939291                   presidency
# 147   -1.491370352889867                      kushner
# 150  -1.4966803774292445                 mcconnell ky
# 151  -1.4975955122158697                      updates
# 152  -1.4980005422130114                      victory
# 153   -1.498030303606754                        digby
# 155  -1.4991392708439624                     photo op
# 157   -1.499574495891183                      falsely
# 158  -1.4998892668213035                       column
# 159   -1.501942732861652                     attorney
# 160   -1.502822941297362                   complained
# 165  -1.5098443861274928                    americans
# 168  -1.5137963899024556                     previous
# 172  -1.5196980912771265                       called
# 182  -1.5326650728507867                         long
# 189  -1.5419084448744274                      refused
# 193  -1.5474641135863174                     reported
# 195  -1.5517126179978393                   bankruptcy
# 196   -1.557582243141587                     demanded
# 197   -1.559458488707399                       battle
# 201  -1.5671951167639238                        lgbtq
# 203  -1.5729810193910996                       sunday
# 205  -1.5742388245059018                       middle
# 206  -1.5760885305959471                      failure
# 209  -1.5803924098861852                 staff writer
# 213  -1.5818712276257536                    treatment
# 216  -1.5853309583535713        contributed reporting
# 217  -1.5884879931644287                       states
# 229  -1.6047304877761817                   downplayed
# 230  -1.6050145286095947                  anti racism
# 234   -1.609225006882768            appeared alternet
# 235  -1.6095714644436687                       noting
# 239  -1.6121316175713225                    currently
# 244  -1.6154108606912436                        basic
# 245  -1.6184468274681332                          new
# 249  -1.6256648117269785                        means
# 250  -1.6270392102671198                       showed
# 251  -1.6279739793875343                         kind
# 254  -1.6312893954095633                        claim
# 261  -1.6391033065375415                    interview
# 270  -1.6497045116492235                      cookies
# 278  -1.6561839749296547                      scandal
# 280  -1.6612197514389344                       herald
# 284   -1.664405441010449                         vice
# 293  -1.6770104116070859                         igor
# 294   -1.678321335765951                      earlier
# 296  -1.6800970391117533                    initially
# 302    -1.68540435467463                covid disease
# 305  -1.6898830917195446                         year
# 310  -1.6947780123185148                       latest
# 312  -1.6962661830333399                       shared
# 313  -1.6987457212243176                    published
# 321  -1.7120317607217834               disease caused
# 324  -1.7131245683907632                    continued
# 326  -1.7165025749901077                     believed
# 329  -1.7245370456387945                  contributed
# 332  -1.7253249709726945                   population
# 334  -1.7284421366660883                      despite
# 335  -1.7290050070926262                     attacked
# 341  -1.7396600450986737                  health care
# 345  -1.7481236864861989                    statement
# 351   -1.755614212191207                      twitter
# 353   -1.759562240231179                         clip
# 366  -1.7797295285294101                      updated
# 372  -1.7862849881304486                         week
# 374  -1.7876969175112898                   check clip
# 384  -1.7968694691535856                       widely
# 391  -1.8100371474885046                        video
# 392    -1.81649759824445                         read
# 394  -1.8187053111855311                      analyst
# 399  -1.8253582378924342                assassination
# 401  -1.8273347191703841                      footage
# 403  -1.8287784012798765                      sunited
# 405  -1.8314296060490178                         anti
# 406  -1.8320041045749997                         care
# 407  -1.8325858262506998                   reelection
# 409   -1.838583160917515                        urged
# 410  -1.8400594958430279                        meant
# 413  -1.8440530416764174                        major
# 418   -1.856732197860341                          old
# 425  -1.8666498823744737                      offered
# 426  -1.8670300927368713                 spokesperson
# 430  -1.8750730099980852                       racist
# 438   -1.887768681592472                     announce
# 443  -1.8975287915291812                    confirmed
# 451   -1.927297978099448                    reporting
# 455   -1.934237239692857                    baltimore
# 461  -1.9433473015196419                      editing
# 462  -1.9465076917333077            guide coronavirus
# 472  -1.9686263349128073                    explained
# 478  -1.9822172403488043                      disease
# 483  -1.9999888757083322                   right wing
# 494  -2.0268962112169935                         live
# 496  -2.0298513224868286                president joe
# 501   -2.039207221411183                        image
# 503    -2.04249117852495                        later
# 504  -2.0468285461010827                        rival
# 509   -2.073124900436218                      critics
# 512   -2.088794908500206                        guide
# 517  -2.0985498107653804                           ky
# 518   -2.104012308710625                    sponsored
# 525   -2.120413847564607                    editorial
# 536   -2.149166895012906                       argued
# 538  -2.1558825840983937                        asked
# 550   -2.205740235301349                     alternet
# 552  -2.2104913024501833                   correction
# 561  -2.2441043800853033                     zelensky
# 562  -2.2575298165334976                         amid
# 565   -2.277779394961138                        calif
# 571  -2.2965376569570197                   previously
# 574  -2.3195098828233185                     reporter
# 586    -2.38611550908163                   democratic
# 601  -2.4625346710243927                  progressive
# 617  -2.5699515192865348                       yougov
# 628  -2.6401104870424112                twitter users
# 631  -2.6684521703648394                   apparently
# 636  -2.6994918955388045                       warned
# 655   -2.863057744541917                        month
# 656  -2.8850607814421827                         host
# 657   -2.886772652902187                       writer
# 658  -2.9093963489601373                    suggested
# 659  -2.9189911070134693                      claimed
# 665  -2.9705439395846747                   repeatedly
# 668  -3.0248621629073473                        covid
# 671  -3.1094767567174983                        users
# 680   -3.192033557546624                   reportedly
# 685   -3.394711012958541  article originally appeared
# 693  -3.5590053846549807                      article
# 702   -3.870103753204572                washington ap
# 703   -3.883255816222963                        check
# 708    -4.14773567813678          originally appeared
# 713   -4.337321383170747           article originally
# 716  -4.6927488948692035                           ap
# 717  -5.1704126298023345                     appeared
# 719   -5.512033913780874                   originally
